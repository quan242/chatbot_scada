# %% [markdown]
# # NLU data reader

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.20.3 in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import re
from typing import List, Dict, Tuple

import pandas as pd
import yaml

NORMAL_REGEX = "\[[^\[\]]+\]\([\w+\s*]+\)"
ENTITY_REGEX = "\[[^\[\]]+\]"
ENTITY_NAME_REGEX = "\([\w+\s*]+\)"
SYNONYM_REGEX = "\[[^\[\]]+\]\{[^{}]+\}"
DATA_REGEX = "\{[^{}]+\}"

# %%
def get_entity_new(df: pd.DataFrame) -> Tuple[pd.DataFrame, Dict[str, set]]:

  entities_list = {}
  for _, row in df.iterrows():
    entity_data = row["entities"]
    if not entity_data:
      entity_data = []

    if isinstance(entity_data, str):
      try:
        entity_data = json.loads(entity_data)
      except Exception as ex:
        raise RuntimeError(f"Cannot convert entity_data to json: {entity_data}")
      
    example = row["example"]
    while True:
      # search for only-object annotation
      x = re.search(NORMAL_REGEX, example)
      if x is None:
        break

      start, end = x.span()
      entity = x.group()

      entity_text = re.search(ENTITY_REGEX, entity).group()[1:-1]
      entity_name_text = re.search(ENTITY_NAME_REGEX, entity).group()[1:-1]

      if entity_name_text not in entities_list:
        entities_list[entity_name_text] = set()
      entities_list[entity_name_text].add("O")

      example = example.replace(entity, entity_text)

      entity_data.append(dict(
          entity=entity_text,
          entity_name=entity_name_text,
          position=(start, end - (len(entity) - len(entity_text)))
      ))

    # row["entities"] = entity_data

    while True:
      #search for detailed annotation
      x = re.search(SYNONYM_REGEX, example)
      if x is None:
        break

      start, end = x.span()
      entity = x.group()

      entity_text = re.search(ENTITY_REGEX, entity).group()[1:-1]
      detailed_text = re.search(DATA_REGEX, entity).group()

      try:
        detailed_data = json.loads(detailed_text)
      except Exception as ex:
        raise ValueError(f"Synonym json is incorrect: {detailed_text}")

      entity_name_text = detailed_data.get("entity", None)
      role_value = detailed_data.get("role", None)

      if entity_name_text is None:
        a = row["intent"]
        b = detailed_data
        raise ValueError(f"this annotation is wrong: {a}; {b}")

      example = example.replace(entity, entity_text)

      if role_value is None:
        if entity_name_text not in entities_list:
          entities_list[entity_name_text] = set()
        entities_list[entity_name_text].add("O")
      else:
        if entity_name_text not in entities_list:
          entities_list[entity_name_text] = set()
        entities_list[entity_name_text].add(role_value)

        entity_name_text = entity_name_text + "|" + role_value

      entity_data.append(dict(
          entity=entity_text,
          entity_name=entity_name_text,
          position=(start, end - (len(entity) - len(entity_text)))
      ))

    row["example"] = example
    row["entities"] = entity_data

  return df, entities_list

# %%
def read_from_yaml(file: str) -> List[Dict[str, str]]:
  """
  params:
  file: file location

  return: list(dict(text, any))
  """
  try:
    f = open(file, "r")
  except Exception as ex:
    raise RuntimeError(f"Cannot read file {file} with error:\t{ex}")

  data = yaml.load(f, Loader=yaml.FullLoader)["nlu"]
  return data

def get_entity(df: pd.DataFrame) -> pd.DataFrame:

  for _, row in df.iterrows():
    entity_data = row["entities"]
    if not entity_data:
      entity_data = []

    while True:
      example = row["example"]
      x = re.search(NORMAL_REGEX, example)
      if x is None:
        break

      start, end = x.span()
      entity = x.group()

      entity_text = re.search(ENTITY_REGEX, entity).group()[1:-1]
      entity_name_text = re.search(ENTITY_NAME_REGEX, entity).group()[1:-1]

      row["example"] = example.replace(entity, entity_text)

      entity_data.append(dict(
          entity=entity_text,
          entity_name=entity_name_text,
          position=(start, end - (len(entity) - len(entity_text)))
      ))

    row["entities"] = entity_data

  return df

def get_entity_with_role(df: pd.DataFrame) -> Tuple[pd.DataFrame, Dict[str, str]]:

  for _, row in df.iterrows():
    entity_data = row["entities"]
    if not entity_data:
      entity_data = []

    if isinstance(entity_data, str):
      try:
        entity_data = json.loads(entity_data)
      except Exception as ex:
        raise RuntimeError(f"Cannot convert entity_data to json: {entity_data}")

    while True:
      example = row["example"]
      x = re.search(SYNONYM_REGEX, example)
      if x is None:
        break

      start, end = x.span()
      entity = x.group()

      entity_text = re.search(ENTITY_REGEX, entity).group()[1:-1]
      role_text = re.search(DATA_REGEX, entity).group()

      try:
        role_data = json.loads(role_text)
      except Exception as ex:
        raise ValueError(f"role json is incorrect: {role_text}")

      entity_name_text = role_data.get("entity", None)
      role_value = role_data.get("role", None)

      if entity_name_text is None or role_value is None:
        raise ValueError(f"synonym data should have 'entity' and 'role' attributes")

      row["example"] = example.replace(entity, entity_text)
      entity_name_text = entity_name_text + "|" + role_value

      entity_data.append(dict(
          entity=entity_text,
          entity_name=entity_name_text,
          position=(start, end -(len(entity) - len(entity_text))),
      ))

    row["entities"] = entity_data

  return df

# %%
def make_dataframe(files: List[str]) -> Tuple[pd.DataFrame, List[str], List[str], Dict[str, str]]:
  """
  params:
  files: list of file location
  return tuple(dataframe, list of entities class name, list of intent class name, synonym dictionary)
  """

  data = []
  synonym_dict = {}
  for file in files:
    data += read_from_yaml(file=file)

  # print(len(data))
  df = pd.DataFrame(columns=["example", "intent", "entities"])

  for intent in data:
    if not intent.get("intent", None):
      if intent.get("synonym", None):
        target_entity = intent["synonym"]

        entities_list_text = intent["examples"]
        if entities_list_text[:2] == "- ":
          entities_list_text = entities_list_text[2:]
        # if entities_list_text[-1:] == "\n":
        #   entities_list_text = entities_list_text[:-1]
        entities_list_text = entities_list_text.rstrip("\n ")

        synonym_entities_list = entities_list_text.split("\n- ")
        for entity in synonym_entities_list:
          synonym_dict[entity] = target_entity

      continue

    intent_name = intent["intent"]
    examples_as_text = intent["examples"]

    if examples_as_text[:2] == "- ":
      examples_as_text = examples_as_text[2:]
    # if examples_as_text[-1:] == "\n":
    #   examples_as_text = examples_as_text[:-1]
    examples_as_text = examples_as_text.rstrip("\n ")

    examples = examples_as_text.split("\n- ")

    new_data = dict(
        intent=[intent_name for i in range(len(examples))],
        example=examples,
        entities=[None for i in range(len(examples))]
    )

    df = pd.concat([df, pd.DataFrame(data=new_data)], ignore_index=True)

  # df = get_entity(df=df)
  # df = get_entity_with_role(df=df)
    
  df, tmp_entities_list = get_entity_new(df=df)

  entities_list = []
  intents_list = []
  for _, row in df.iterrows():
    if row["intent"] not in intents_list:
      intents_list.append(row["intent"])

  for entity_name, roles_list in tmp_entities_list.items():
    if len(roles_list) == 0:
      entities_list.append(entity_name)
    else:
      for role in roles_list:
        if role != "O":
          entities_list.append(entity_name + "|" + role)
        else:
          entities_list.append(entity_name)
  return df, entities_list, intents_list, synonym_dict

# %%
files = ["/workspace/nlplab/quannd/scada-full-stack/chatbot-scada/data/nlu.yml"]
df, entities_list, intents_list, synonym_dict = make_dataframe(files)
print(df["example"])
print(entities_list)
print(intents_list)
print(synonym_dict)
# Out:
# 0                                                     alo
# 1                                                chào bot
# 2                                                   hello
# 3                                                    chào
# 4            Xin chào, làm ơn cho phép tôi tự giới thiệu.
#                               ...
# 2182    Tìm [tam giác]{"entity": "object", "role": "sh...
# 2183    Chọn [tam giác]{"entity": "object", "role": "s...
# 2184    Tìm [tam giác]{"entity": "object", "role": "sh...
# 2185    Chọn [tam giác]{"entity": "object", "role": "s...
# 2186    Tìm [tam giác]{"entity": "object", "role": "sh...
# Name: example, Length: 2187, dtype: object
# ['object|length', 'object|height', 'object|size', 'object|angle', 'object|shape', 'object|orientation', 'object|width', 'object|color', 'object', 'object|thickness', 'comparison', 'aspect', 'position|destination_x', 'position|source_y', 'position|destination', 'position|center_x', 'position|destination_y', 'position|source_x', 'position|source', 'position', 'position|center_y', 'selected_area|length', 'selected_area|height', 'selected_area|width', 'value|change', 'value|angle', 'value|color', 'value|move', 'change_action']
# ['greet', 'stop', 'affirm', 'deny', 'goodbye', 'bot_challenge', 'select_all_object', 'exit_select', 'delete_selected_objects', 'select_area', 'rotate_left', 'rotate_right', 'horizontal_flip', 'vertical_flip', 'move_left', 'move_right', 'move_up', 'move_down', 'color_background', 'color_foreground', 'change_width', 'change_height', 'change_length', 'change_radius', 'change_top', 'change_left', 'change_right', 'change_bottom', 'draw_line', 'draw_circle', 'draw_ellipse', 'draw_rectangle', 'draw_square', 'draw_rhombus', 'draw_parallelogram', 'draw_trapezoid', 'draw_arrow', 'copy_selected_objects', 'cut_selected_objects', 'paste', 'undo', 'redo', 'select_object']
# {'làm sáng': 'chọn', 'Làm sáng': 'chọn', 'làm nột bật': 'chọn', 'tìm': 'chọn', 'Tìm': 'chọn', 'lưu thông tin': 'chọn', 'ghim': 'chọn', 'Ghim': 'chọn', 'tìm kiếm': 'chọn', 'Tìm kiếm': 'chọn', 'đánh dấu': 'chọn', 'Đánh dấu': 'chọn', 'tra': 'chọn', 'Tra': 'chọn', 'Trỏ': 'chọn', 'trỏ': 'chọn', 'Choose': 'chọn', 'choose': 'chọn', 'Select': 'chọn', 'select': 'chọn', 'Click': 'chọn', 'click': 'chọn', 'Hủy': 'bỏ', 'hủy': 'bỏ', 'Loại': 'bỏ', 'loại': 'bỏ', 'Tháo': 'bỏ', 'tháo': 'bỏ', 'Thoát': 'bỏ', 'thoát': 'bỏ', 'Ngừng': 'bỏ', 'ngừng': 'bỏ', 'Dừng': 'bỏ', 'dừng': 'bỏ', 'Tạm dừng': 'bỏ', 'tạm dừng': 'bỏ', 'Exit': 'bỏ', 'exit': 'bỏ', 'Cancel': 'bỏ', 'cancel': 'hoàn tác', 'Stop': 'bỏ', 'stop': 'bỏ', 'tất cả': 'toàn bộ', 'all': 'toàn bộ', 'mọi thứ': 'toàn bộ', 'đầy đủ': 'toàn bộ', 'không bỏ sót': 'toàn bộ', 'Loại bỏ': 'xóa', 'loại bỏ': 'xóa', 'drop': 'xóa', 'Drop': 'xóa', 'remove': 'xóa', 'Remove': 'xóa', 'Gạch': 'xóa', 'gạch': 'xóa', 'Delete': 'xóa', 'delete': 'xóa', 'Clear': 'xóa', 'clear': 'xóa', 'Clean': 'xóa', 'clean': 'xóa', 'Xoay ': 'xoay', 'Quay': 'xoay', 'quay': 'xoay', 'Nghiêng': 'xoay', 'nghiêng': 'xoay', 'Đảo': 'xoay', 'đảo': 'xoay', 'rotate': 'xoay', 'Rotate': 'xoay', 'spin': 'xoay', 'Spin': 'xoay', 'dịch': 'di chuyển', 'Dịch': 'di chuyển', 'dịch chuyển': 'di chuyển', 'Dịch chuyển': 'di chuyển', 'dời': 'di chuyển', 'Dời': 'di chuyển', 'Di dời': 'di chuyển', 'di dời': 'di chuyển', 'move': 'di chuyển', 'Move': 'di chuyển', 'Đặt màu': 'tô màu', 'đặt màu': 'tô màu', 'Phối màu': 'tô màu', 'phối màu': 'tô màu', 'Nhuộm màu': 'tô màu', 'nhuộm màu': 'tô màu', 'Lên màu': 'tô màu', 'lên màu': 'tô màu', 'Điểm màu': 'tô màu', 'điểm màu': 'tô màu', 'color': 'tô màu', 'Color': 'tô màu', 'dye': 'tô màu', 'Dye': 'tô màu', 'shade': 'tô màu', 'Shade': 'tô màu', 'phông': 'nền', 'background': 'nền', 'nâng': 'tăng', 'kéo dài': 'tăng', 'mở rộng': 'tăng', 'cơi nới': 'tăng', 'làm rộng': 'tăng', 'làm gài': 'tăng', 'thêm': 'tăng', 'increase': 'tăng', 'lengthen': 'tăng', 'extend': 'tăng', 'cộng': 'tăng', 'bổ sung': 'tăng', 'hạ': 'giảm', 'thu hẹp': 'giảm', 'cắt ngắn': 'giảm', 'làm gọn': 'giảm', 'làm ngắn': 'giảm', 'cắt gọn': 'giảm', 'bớt': 'giảm', 'trừ': 'giảm', 'thiết lập': 'thay đổi', 'làm mới': 'thay đổi', 'đặt lại': 'thay đổi', 'cập nhật': 'thay đổi', 'update': 'thay đổi', 'reset': 'hoàn tác', 'gán': 'thay đổi', 'tạo': 'vẽ', 'minh họa': 'vẽ', 'hình thành': 'vẽ', 'xây dựng': 'vẽ', 'thiết kế': 'vẽ', 'khắc': 'vẽ', 'chế': 'vẽ', 'ellipse': 'ê-líp', 'elip': 'ê-líp', 'bầu dục': 'ê-líp', 'oval': 'ê-líp', 'ô-van': 'ê-líp', 'dài': 'chiều dài', 'chiều lớn': 'chiều dài', 'đáy lớn': 'chiều dài', 'đáy': 'chiều dài', 'trục lớn': 'chiều dài', 'trục chính': 'chiều dài', 'đường chéo chính': 'chiều dài', 'đường kính': 'chiều dài', 'cạnh dài': 'chiều dài', 'độ dài': 'chiều dài', 'rộng': 'chiều rộng', 'chiều nhỏ': 'chiều rộng', 'đáy bé': 'chiều rộng', 'đảy nhỏ': 'chiều rộng', 'trục nhỏ': 'chiều rộng', 'đường chéo phụ': 'chiều rộng', 'trục phụ': 'chiều rộng', 'bán kinh': 'chiều rộng', 'cạnh ngắn': 'chiều rộng', 'độ rộng': 'chiều rộng', 'đường cao': 'chiều cao', 'độ cao': 'chiều cao', 'độ sâu': 'chiều cao', 'góc trái trên': 'góc trái trên', 'phía trên bên trái': 'góc trái trên', 'bên trái góc trên': 'góc trái trên', 'trên cùng bên trái': 'góc trái trên', 'trên bên trái': 'góc trái trên', 'phía trái bên trên': 'góc trái trên', 'trái trên': 'góc trái trên', 'trên trái': 'góc trái trên', '-\tgóc phải trên\n-\tphía trên bên phải\n-\tbên phải góc trên\n-\ttrên cùng bên phải\n-\ttrên bên phải\n-\tphía phải bên trên\n-\tphải trên\n-\ttrên phải': 'góc phải trên', '-\tgóc phải dưới\n-\tphía dưới bên phải\n-\tbên phải góc dưới\n-\tdưới cùng bên phải\n-\tdưới bên phải\n-\tphía phải bên dưới\n-\tphải dưới\n-\tdưới phải': 'góc phải dưới', '-\tgóc trái dưới\n-\tphía dưới bên trái\n-\tbên trái góc dưới\n-\tdưới cùng bên trái\n-\tdưới bên trái\n-\tphía trái bên dưới\n-\ttrái dưới\n-\tdưới trái': 'góc trái dưới', '-\tphía giữa\n-\tchính giữa\n-\ttrung tâm': 'giữa', '-\tkhởi đầu\n-\tmở đầu': ...

# %%
type(df.loc[df['intent'] == 'draw_line'])
# Out:
# pandas.core.frame.DataFrame

# %%
for intent in intents_list:
    print(f"- {intent}")
# Out:
# - greet
# - stop
# - affirm
# - deny
# - goodbye
# - bot_challenge
# - select_all_object
# - exit_select
# - delete_selected_objects
# - select_area
# - rotate_left
# - rotate_right
# - horizontal_flip
# - vertical_flip
# - move_left
# - move_right
# - move_up
# - move_down
# - color_background
# - color_foreground
# - change_width
# - change_height
# - change_length
# - change_radius
# - change_top
# - change_left
# - change_right
# - change_bottom
# - draw_line
# - draw_circle
# - draw_ellipse
# - draw_rectangle
# - draw_square
# - draw_rhombus
# - draw_parallelogram
# - draw_trapezoid
# - draw_arrow
# - copy_selected_objects
# - cut_selected_objects
# - paste
# - undo
# - redo
# - select_object

# %%
entity_type = "selected_area"
for entity in entities_list:
    if entity.startswith(entity_type):
        if len(entity.split("|")) > 1:
            print(entity.split("|")[1])
# Out:
# length
# height
# width

# %%
for intent in intents_list:
    print(intent, ": ", len(df.loc[df["intent"] == intent]))
# Out:
# greet :  3
# stop :  6
# affirm :  5
# deny :  5
# goodbye :  6
# bot_challenge :  7
# select_all_object :  50
# exit_select :  50
# delete_selected_objects :  44
# select_area :  40
# rotate_left :  54
# rotate_right :  54
# horizontal_flip :  54
# vertical_flip :  54
# move_left :  54
# move_right :  54
# move_up :  54
# move_down :  54
# color_background :  53
# color_foreground :  55
# change_width :  54
# change_height :  54
# change_length :  54
# change_radius :  54
# change_top :  54
# change_left :  64
# change_right :  54
# change_bottom :  54
# draw_line :  89
# draw_circle :  70
# draw_ellipse :  68
# draw_rectangle :  68
# draw_square :  67
# draw_rhombus :  67
# draw_parallelogram :  58
# draw_trapezoid :  68
# draw_arrow :  68
# copy_selected_objects :  49
# cut_selected_objects :  54
# paste :  45
# undo :  48
# redo :  49
# select_object :  71

# %%
df['intent'].value_counts()
# Out:
# intent
# select_object              71
# draw_line                  70
# draw_parallelogram         58
# cut_selected_objects       54
# rotate_right               54
# draw_circle                51
# move_left                  51
# select_all_object          50
# exit_select                50
# move_up                    50
# draw_rectangle             49
# draw_ellipse               49
# change_bottom              49
# change_right               49
# change_top                 49
# draw_trapezoid             49
# draw_rhombus               49
# move_right                 49
# copy_selected_objects      49
# redo                       49
# draw_arrow                 48
# undo                       48
# draw_square                48
# color_background           46
# change_height              45
# change_left                45
# paste                      45
# change_width               44
# delete_selected_objects    44
# move_down                  44
# color_foreground           43
# rotate_left                43
# vertical_flip              41
# change_length              40
# change_radius              40
# horizontal_flip            40
# select_area                40
# bot_challenge               7
# stop                        6
# goodbye                     6
# affirm                      5
# greet                       3
# Name: count, dtype: int64

# %%
" ".join(vncore_segmenter.word_segment(df['example'][102]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 " ".join(vncore_segmenter.word_segment(df['example'][102]))
#
# NameError: name 'vncore_segmenter' is not defined

# %%
for sent in df.loc[df['intent'] == 'draw_rectangle']['example']:
  print("- " + sent)
# Out:
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} [nằm ngang]{"entity": "value", "role": "orientation"} có [kích thước]{"entity": "aspect"} ([43]{"entity": "value", "role": "length"}, [20]){"entity": "value", "role": "width"} ở [vị trí]{"entity": "aspect"} ([40]{"entity": "position", "role": "source_x"}, [60]{"entity": "position", "role": "source_y"}).
# - Vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xám]{"entity": "value", "role": "color"} nằm ở [giữa]{"entity": "position", "role": "source"} màn hình.
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} [lớn]{"entity": "value", "role": "size"} màu [trắng]{"entity": "value", "role": "color"} ở [góc dưới bên phải]{"entity": "position", "role": "source"}.
# - Vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} [nhỏ]{"entity": "value", "role": "size"} màu [đen]{"entity": "value", "role": "color"} ở [góc trên bên trái]{"entity": "position", "role": "source"}.
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [nâu]{"entity": "value", "role": "color"} ở [tọa độ]{"entity": "aspect"} ([150]{"entity": "position", "role": "source_x"}, [250]{"entity": "position", "role": "source_y"}) với [chiều dài]{"entity": "aspect"} [60 pixel]{"entity": "value", "role": "length"} và [chiều rộng]{"entity": "aspect"} [30 pixel]{"entity": "value", "role": "width"}.
# - Hãy vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} [đứng]{"entity": "value", "role": "orientation"} màu [xanh đậm]{"entity": "value", "role": "color"} với [chiều dài]{"entity": "aspect"} [70 pixel]{"entity": "value", "role": "length"} và [chiều rộng]{"entity": "aspect"} [50 pixel]{"entity": "value", "role": "width"}.
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [nâu]{"entity": "value", "role": "color"} từ [tọa độ]{"entity": "aspect"} ([14]{"entity": "position", "role": "source_x"}, [35]{"entity": "position", "role": "source_y"}) đến [tọa độ]{"entity": "aspect"} ([54]{"entity": "position", "role": "destination_x"}, [42]{"entity": "position", "role": "destination_y"}).
# - Vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} với [kích thước]{"entity": "aspect"} ([53]{"entity": "value", "role": "length"}, [100]{"entity": "value", "role": "width"}) và có màu [đen]{"entity": "value", "role": "color"} ở [tọa độ]{"entity": "aspect"} ([76]{"entity": "position", "role": "source_x"}, [43]{"entity": "position", "role": "source_y"}).
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"} ở [tọa độ]{"entity": "aspect"} ([150]{"entity": "position", "role": "source_x"}, [250]{"entity": "position", "role": "source_y"}) với [chiều dài]{"entity": "aspect"} [32 cm]{"entity": "value", "role": "length"} và [chiều rộng]{"entity": "aspect"} [12 cm]{"entity": "value", "role": "width"}.
# - Hãy vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"} với [chiều dài]{"entity": "aspect"} [70 pixel]{"entity": "value", "role": "length"} và [chiều rộng]{"entity": "aspect"} [50 pixel]{"entity": "value", "role": "width"}.
# - Vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xám]{"entity": "value", "role": "color"} nằm ở [giữa]{"entity": "position", "role": "source"} màn hình.
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [nâu]{"entity": "value", "role": "color"} từ [tọa độ]{"entity": "aspect"} ([14]{"entity": "position", "role": "source_x"}, [35]{"entity": "position", "role": "source_y"}) đến [tọa độ]{"entity": "aspect"} ([54]{"entity": "position", "role": "destination_x"}, [42]{"entity": "position", "role": "destination_y"}).
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} có [độ dày đường viền]{"entity": "aspect"} [3 pixel]{"entity": "value", "role": "thickness"}, [chiều rộng]{"entity": "aspect"} [75]{"entity": "value", "role": "width"} và [chiều cao]{"entity": "aspect"} [50]{"entity": "value", "role": "height"} ở [tọa độ]{"entity": "aspect"} ([200]{"entity": "position", "role": "source_x"}, [200]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh lá cây]{"entity": "value", "role": "color"} có [độ dày đường viền]{"entity": "aspect"} [3 pixel]{"entity": "value", "role": "thickness"}, [chiều rộng]{"entity": "aspect"} [75]{"entity": "value", "role": "width"} và [chiều cao]{"entity": "aspect"} [50]{"entity": "value", "role": "height"} ở [tọa độ]{"entity": "aspect"} ([150]{"entity": "position", "role": "source_x"}, [150]{"entity": "position", "role": "source_y"})
# - Vui lòng vẽ một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [cam]{"entity": "value", "role": "color"}, có [kích thước]{"entity": "aspect"} [70]{"entity": "value", "role": "width"}x[30]{"entity": "value", "role": "height"}, ở [phía trên bên phải]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} có [độ dày đường viền]{"entity": "aspect"} [3 pixel]{"entity": "value", "role": "thickness"}, [chiều rộng]{"entity": "aspect"} [75]{"entity": "value", "role": "width"} và [chiều cao]{"entity": "aspect"} [50]{"entity": "value", "role": "height"} ở [tọa độ]{"entity": "aspect"} ([200]{"entity": "position", "role": "source_x"}, [200]{"entity": "position", "role": "source_y"})
# - Hãy vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [tím]{"entity": "value", "role": "color"} có [chiều rộng]{"entity": "aspect"} [80]{"entity": "value", "role": "width"}, [chiều cao]{"entity": "aspect"} [60]{"entity": "value", "role": "height"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} có [chiều rộng]{"entity": "aspect"} [55]{"entity": "value", "role": "width"}, màu [xanh lá cây]{"entity": "value", "role": "color"}, ở [giữa]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} có [chiều rộng]{"entity": "aspect"} [55]{"entity": "value", "role": "width"}, màu [tím]{"entity": "value", "role": "color"}, tại [vị trí]{"entity": "aspect"} [bên phải]{"entity": "position", "role": "source"}
# - Tạo một hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"}, [kích thước]{"entity": "aspect"} [90]{"entity": "value", "role": "width"}x[50]{"entity": "value", "role": "height"}, nằm ở [vị trí]{"entity": "aspect"} ([200]{"entity": "position", "role": "source_x"}, [250]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} có [chiều rộng]{"entity": "aspect"} [55]{"entity": "value", "role": "width"}, [chiều cao]{"entity": "aspect"} [45]{"entity": "value", "role": "height"}, màu [hồng]{"entity": "value", "role": "color"}, ở [vị trí]{"entity": "aspect"} ([350]{"entity": "position", "role": "source_x"}, [150]{"entity": "position", "role": "source_y"})
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} với [chiều rộng]{"entity": "aspect"} [60]{"entity": "value", "role": "width"}, [chiều cao]{"entity": "aspect"} [10]{"entity": "value", "role": "height"}, màu [xanh lục]{"entity": "value", "role": "color"},ở [giữa trang]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật ]{"entity": "value", "role": "shape"}màu [cam]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [120]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [80]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [50]{"entity": "position", "role": "source_x"} , [50]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh lá cây]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [60]{"entity": "value", "role": "length"} , [chiều cao]{"entity": "aspect"} [30]{"entity": "value", "role": "height"} , ở [vị trí]{"entity": "aspect"} ( [200]{"entity": "position", "role": "source_x"} , [300]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [100]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [50]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu nâu , ở [phía dưới bên trái]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [hồng]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [70]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [35]{"entity": "value", "role": "width"} , ở [vị trí]{"entity": "aspect"} ( [300]{"entity": "position", "role": "source_x"} , [200]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh dương]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [90]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [60]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [giữa]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [tím]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [45]{"entity": "value", "role": "length"} , [chiều cao]{"entity": "aspect"} [25]{"entity": "value", "role": "height"} , ở [vị trí]{"entity": "aspect"} ( [150]{"entity": "position", "role": "source_x"} , [250]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đen]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [110]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [70]{"entity": "value", "role": "height"} , ở [vị trí]{"entity": "aspect"} ( [250]{"entity": "position", "role": "source_x"} , [150]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xám]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [85]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [55]{"entity": "value", "role": "width"} , ở [phía trên bên phải]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [nâu]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [75]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [40]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [180]{"entity": "position", "role": "source_x"} , [120]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [50]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [30]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [giữa]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh lục]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [65]{"entity": "value", "role": "length"} , [chiều cao]{"entity": "aspect"} [45]{"entity": "value", "role": "height"} , ở [vị trí]{"entity": "aspect"} ( [300]{"entity": "position", "role": "source_x"} , [350]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [cam]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [80]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [55]{"entity": "value", "role": "height"} , ở [vị trí]{"entity": "aspect"} ( [120]{"entity": "position", "role": "source_x"} , [180]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [95]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [60]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [phía trên bên phải]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh dương]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [70]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [40]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [250]{"entity": "position", "role": "source_x"} , [300]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [hồng]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [55]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [35]{"entity": "value", "role": "width"} , ở [phía dưới bên trái]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [60]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [20]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [giữa]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh lá cây]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [75]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [45]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [200]{"entity": "position", "role": "source_x"} , [250]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [tím]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [85]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [50]{"entity": "value", "role": "height"} , ở [phía trên bên phải]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [65]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [30]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [180]{"entity": "position", "role": "source_x"} , [280]{"entity": "position", "role": "source_y"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [cam]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [55]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [25]{"entity": "value", "role": "height"} , ở [phía dưới bên trái]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [hồng]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [80]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [40]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [giữa]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đen]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [90]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [60]{"entity": "value", "role": "height"} , ở [vị trí]{"entity": "aspect"} ( [250]{"entity": "position", "role": "source_x"} , [200]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "aspect"} màu [xanh lục]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [75]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [35]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [phía trên bên phải]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [70]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [30]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [200]{"entity": "position", "role": "source_x"} , [300]{"entity": "position", "role": "source_y"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [xanh dương]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [45]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [20]{"entity": "value", "role": "width"} , ở [phía dưới bên phải]{"entity": "position", "role": "source"}
# - Vẽ hình [chữ nhật]{"entity": "value", "role": "shape"} màu [cam]{"entity": "value", "role": "color"} , [chiều rộng]{"entity": "aspect"} [85]{"entity": "value", "role": "width"} , [chiều cao]{"entity": "aspect"} [50]{"entity": "value", "role": "height"} , [đường viền]{"entity": "aspect"} màu đen , ở [giữa]{"entity": "position", "role": "source"}
# - Tạo hình [chữ nhật]{"entity": "value", "role": "shape"} màu [nâu]{"entity": "value", "role": "color"} , [chiều dài]{"entity": "aspect"} [60]{"entity": "value", "role": "length"} , [chiều rộng]{"entity": "aspect"} [35]{"entity": "value", "role": "width"} , [đường viền]{"entity": "aspect"} màu đen , ở [vị trí]{"entity": "aspect"} ( [150]{"entity": "position", "role": "source_x"} , [220]{"entity": "position", "role": "source_y"}

# %%
df['segmented_example'] = df.apply(lambda x: " ".join(vncore_segmenter.word_segment(x['example'])), axis=1)

# %%
entity_list = set()
for entity in entities_list:
  entity_list.add(entity.split("|")[0])
entity_list
# Out:
# {'aspect',
#  'change_action',
#  'comparison',
#  'intent',
#  'object',
#  'position',
#  'selected_area',
#  'value'}

# %%
len(intents_list)
# Out:
# 42

# %%
len(entities_list)
# Out:
# 42

# %%
for intent in intents_list:
  print("-", intent)
# Out:
# - greet
# - stop
# - affirm
# - goodbye
# - bot_challenge
# - rotate_left
# - rotate_right
# - horizontal_flip
# - vertical_flip
# - move_left
# - move_right
# - move_up
# - move_down
# - select_object
# - select_all_object
# - exit_select
# - select_area
# - delete_selected_objects
# - color_background
# - color_foreground
# - change_width
# - change_height
# - change_length
# - change_radius
# - change_top
# - change_left
# - change_right
# - change_bottom
# - draw_circle
# - draw_ellipse
# - draw_rectangle
# - draw_square
# - draw_rhombus
# - draw_parallelogram
# - draw_trapezoid
# - draw_line
# - draw_arrow
# - copy_selected_objects
# - cut_selected_objects
# - paste
# - redo
# - undo

# %%
print(df["example"][102])
# Out:
# quay phải một [góc nhọn]{"entity": "value", "role": "angle"}

# %%
from collections import defaultdict

# %%
for sent in df["example"]:
  print(sent)
# Out:
# alo
# chào bot
# hello
# dừng thực hiện tác vụ tại đây
# dừng lại
# không làm nữa
# hủy bỏ tác vụ
# stop
# tôi không muốn làm cái này nữa
# ừ
# đúng rồi
# đúng là như vậy
# chuẩn rùi
# chính xác
# tạm biệt
# hẹn lần sau gặp lại
# see ya
# bye
# pai
# paipai
# cu có phải bot real ko ?
# cậu là sinh viên trường nào thế ?
# Hãy giới thiệu bản thân cho tớ nghe đi.
# huh ?
# Cậu là bot hay là người thế ?
# thế cậu là người hay là bot vậy ?
# cậu là bot hay là người thế ?
# Xoay hình [chữ nhật]{"entity": "object", "role": "shape"} ở [góc trái trên]{"entity": "position", "role": "source"} về bên trái.
# Quay hình [ê-líp]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} sang trái
# Làm xoay hình [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"}) qua phía trái
# Quay trái hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [70]{"entity": "position", "role": "source_y"}).
# Quay hình [oval]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"} về bên trái đi một góc [90 độ]{"entity": "value", "role": "angle"}.
# Điều chỉnh xoay hình [ngôi sao]{"entity": "object", "role": "shape"} tại [vị trí]{"entity": "aspect"} ([100]{"entity": "position", "role": "source_x"}, [150]{"entity": "position", "role": "source_y"}) sang trái [180 độ]{"entity": "value", "role": "angle"}.
# xoay sang trái.
# xoay trái tất cả hình [vuông]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"} ở [góc trên bên phải]{"entity": "position", "role": "source"}.
# xoay hình [vuông]{"entity": "object", "role": "shape"} sang trái.
# xoay hình [vuông]{"entity": "object", "role": "shape"} có màu [đen]{"entity": "object", "role": "color"} sang trái khoảng [45 độ]{"entity": "value", "role": "angle"}.
# xoay hình [chữ nhật]{"entity": "object", "role": "shape"} màu [hồng]{"entity": "object", "role": "color"} sang trái
# xoay hình [chữ nhật]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([40]{"entity": "position", "role": "source_x"}, [50]{"entity": "position", "role": "source_y"}) sang trái
# xoay trái các vật thể trong vùng [bắt đầu]{"entity": "aspect"} từ [tọa độ]{"entity": "aspect"} ([24]{"entity": "position", "role": "source_x"}, [40]{"entity": "position", "role": "source_y"}) và có [kích thước]{"entity": "aspect"} ([543]{"entity": "selected_area", "role": "length"}, [242]{"entity": "selected_area", "role": "width"}) khoảng [45 độ]{"entity": "value", "role": "angle"}.
# xoay hình [chữ nhật]{"entity": "object", "role": "shape"} sang trái khoảng [13 độ]{"entity": "value", "role": "angle"}.
# xoay hình [chữ nhật]{"entity": "object", "role": "shape"} màu [xám]{"entity": "object", "role": "color"} sang trái.
# xoay trái hình [chữ nhật]{"entity": "object", "role": "shape"} khoảng [45 độ]{"entity": "value", "role": "angle"}
# Nghiêng hình [chữ nhật]{"entity": "object", "role": "shape"} có [chiều dài]{"entity": "aspect"} [cạnh]{"entity": "aspect"} [15 cm]{"entity": "object", "role": "width"} sang bên trái khoảng [45 độ]{"entity": "value", "role": "angle"}.
# Nghiêng trái hình [bình hành]{"entity": "object", "role": "shape"} có [chiều cao]{"entity": "aspect"} [200 pixel]{"entity": "aspect"} và [chiều dài]{"entity": "aspect"} [đáy]{"entity": "aspect"} [200 pixel]{"entity": "object", "role": "length"}.
# quay hình [vuông]{"entity": "object", "role": "shape"}
# quay trái [90 độ]{"entity": "value", "role": "angle"}
# rotate trái [25 độ]{"entity": "value", "role": "angle"}
# quay trái [mũi tên]{"entity": "object", "role": "shape"}
# okee vậy quay trái 1 [góc tù]{"entity": "value", "role": "angle"}
# trái quay
# trái xoay
# bên trái , quay [15 độ]{"entity": "value", "role": "angle"}
# quay hình [vuông]{"entity": "object", "role": "shape"}
# quay trái [90 độ]{"entity": "value", "role": "angle"}
# rotate trái [25 độ]{"entity": "value", "role": "angle"}
# quay trái [mũi tên]{"entity": "object", "role": "shape"}
# okee vậy quay trái 1 [góc tù]{"entity": "value", "role": "angle"}
# trái quay
# trái xoay
# bên trái , quay [15 độ]{"entity": "value", "role": "angle"}
# Xoay hình vuông tại tọa độ ( [5]{"entity": "position", "role": "source_x"} , [10]{"entity": "position", "role": "source_y"} ) sang trái [60 độ]{"entity": "value", "role": "angle"}
# Làm xoay hình tam giác tại tọa độ ( [8]{"entity": "position", "role": "source_x"} , [15]{"entity": "position", "role": "source_y"} ) sang trái [45 độ]{"entity": "value", "role": "angle"}
# Xoay toàn bộ hình đã chọn sang trái một góc xoay tương đối [nhỏ]{"entity": "value", "role": "angle"}
# Xoay hình chữ nhật đã chọn sang trái [75 độ]{"entity": "value", "role": "angle"}
# Thực hiện xoay hình tròn tại tọa độ ( [2]{"entity": "position", "role": "source_x"} , [5]{"entity": "position", "role": "source_y"} ) sang trái [120 độ]{"entity": "value", "role": "angle"}
# Xoay hình thang sang trái [30 độ]{"entity": "value", "role": "angle"}
# Xoay hình tam giác đã chọn sang trái [90 độ]{"entity": "value", "role": "angle"}
# Thực hiện xoay đối tượng chữ nhật tại tọa độ ( [12]{"entity": "position", "role": "source_x"} , [8]{"entity": "position", "role": "source_y"} ) sang trái [50 độ]{"entity": "value", "role": "angle"}
# Xoay hình tròn hiện tại sang trái [180 độ]{"entity": "value", "role": "angle"}
# Xoay vật thể hình [chữ nhật]{"entity": "object", "role": "shape"} ở [góc trái trên]{"entity": "position", "role": "source"} về bên phải
# Quay đối tượng hình [tròn]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} sang phải
# Làm xoay vật thể [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"}) qua phía phải
# Quay phải đối tượng hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [70]{"entity": "position", "role": "source_y"})
# Quay vật thể hình [oval]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"} về bên phải một góc [45 độ]{"entity": "value", "role": "angle"}
# Điều chỉnh xoay vật thể hình [ngôi sao]{"entity": "object", "role": "shape"} tại [vị trí]{"entity": "aspect"} ([100]{"entity": "position", "role": "source_x"}, [150]{"entity": "position", "role": "source_y"}) sang phải [270 độ]{"entity": "value", "role": "angle"}
# xoay hình [chữ nhật]{"entity": "object", "role": "shape"} sang phải
# xoay hình [vuông]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"}) sang phải [45 độ]{"entity": "value", "role": "angle"}
# xoay phải hình [vuông]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"}
# xoay phải hình [chữ nhật]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} [chính giữa]{"entity": "position", "role": "source"} màn hình
# xoay phải
# xoay hình [vuông]{"entity": "object", "role": "shape"} sang phải
# xoay hình [vuông]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} [góc trên bên phải]{"entity": "position", "role": "source"} sang phải
# xoay tất cả hình [vuông]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} [góc trên bên phải]{"entity": "position", "role": "source"} sang phải
# xoay hình [vuông]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} [chính giữa]{"entity": "position", "role": "source"} màn hình sang phải
# xoay hình [vuông]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} [chính giữa]{"entity": "position", "role": "source"} màn hình sang phải
# xoay hình [vuông]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} [chính giữa]{"entity": "position", "role": "source"} màn hình sang phải
# Nghiêng hình [thoi]{"entity": "object", "role": "shape"} có [kích thước]{"entity": "aspect"} [100]{"entity": "object", "role": "length"}x[150]{"entity": "object", "role": "width"} sang bên phải.
# Nghiêng hình [ellipse]{"entity": "object", "role": "shape"} có [bán trục lớn]{"entity": "aspect"} [150 pixel]{"entity": "object", "role": "length"} và [bán trục bé]{"entity": "aspect"} [50 pixel]{"entity": "object", "role": "width"} ở [vị trí]{"entity": "aspect"} [góc phải dưới]{"entity": "position", "role": "source"} sang bên phải khoảng [45 độ]{"entity": "value", "role": "angle"}.
# bên phải , xoay [vuông góc]{"entity": "value", "role": "angle"}
# bên phải , quay [99 độ]{"entity": "value", "role": "angle"}
# quay phải một [góc nhọn]{"entity": "value", "role": "angle"}
# xoay sang phải [128 độ]{"entity": "value", "role": "angle"}
# quay cho tôi sang phải nhé
# xoay về phía bên phải kìa
# tôi bảo quay về phía bên phải [93 độ]{"entity": "value", "role": "angle"}
# ồi bạn trợ lý đẹp trai xinh gái quay cho tôi hình này sang phải nhé
# ồi bạn trợ lý đẹp trai xinh gái quay cho tôi hình này sang phải nhé
# rotate right
# đảo sang phải [45 độ]{"entity": "value", "role": "angle"}
# bên phải , xoay [vuông góc]{"entity": "value", "role": "angle"}
# bên phải , quay [99 độ]{"entity": "value", "role": "angle"}
# quay phải một [góc nhọn]{"entity": "value", "role": "angle"}
# xoay sang phải [128 độ]{"entity": "value", "role": "angle"}
# quay cho tôi sang phải nhé
# xoay về phía bên phải kìa
# tôi bảo quay về phía bên phải [93 độ]{"entity": "value", "role": "angle"}
# ồi bạn trợ lý đẹp trai xinh gái quay cho tôi hình này sang phải nhé
# rotate right
# đảo sang phải [45 độ]{"entity": "value", "role": "angle"}
# Xoay đối tượng tương đối so với vị trí hiện tại , góc xoay là [15 độ]{"entity": "value", "role": "angle"}
# Xoay đối tượng hiện tại sang phải [30 độ]{"entity": "value", "role": "angle"}
# Xoay hình vuông tại tọa độ ( [5]{"entity": "position", "role": "source_x"} , [10]{"entity": "position", "role": "source_y"} ) sang phải [60 độ]{"entity": "value", "role": "angle"}
# Thực hiện xoay đối tượng đang được chọn với góc xoay là [90 độ]{"entity": "value", "role": "angle"}
# Xoay [tam giác]{"entity": "object", "role": "shape"} đối tượng tại tọa độ ( [8]{"entity": "position", "role": "source_x"} , [15]{"entity": "position", "role": "source_y"} ) sang phải [45 độ]{"entity": "value", "role": "angle"}
# Xoay toàn bộ hình ảnh sang phải một góc xoay tương đối [nhỏ]{"entity": "value", "role": "angle"}
# Xoay toàn bộ hình ảnh sang phải một [góc xoay]{"entity": "aspect"} [tương đối nhỏ]{"entity": "value", "role": "angle"}
# Xoay hình chữ nhật đã chọn sang phải [75 độ]{"entity": "value", "role": "angle"}
# Thực hiện xoay hình [tròn]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [2]{"entity": "position", "role": "source_x"} , [5]{"entity": "position", "role": "source_y"} ) sang phải [120 độ]{"entity": "value", "role": "angle"}
# Xoay một hình [thang]{"entity": "object", "role": "shape"} đối tượng sang phải [30 độ]{"entity": "value", "role": "angle"} từ [vị trí]{"entity": "aspect"}
# Xoay đối tượng tương đối so với [vị trí]{"entity": "aspect"} hiện tại , [góc]{"entity": "aspect"} xoay là sang phải [15 độ]{"entity": "value", "role": "angle"}
# Xoay hình [tam giác]{"entity": "object", "role": "shape"} đã chọn sang phải [90 độ]{"entity": "value", "role": "angle"}
# Thực hiện xoay đối tượng [chữ nhật]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [12]{"entity": "position", "role": "source_x"} , [8]{"entity": "position", "role": "source_y"} ) sang phải [50 độ]{"entity": "value", "role": "angle"}
# Xoay hình [tròn]{"entity": "object", "role": "shape"} hiện tại sang phải [180 độ]{"entity": "value", "role": "angle"}
# Lật ngang vật thể hình [chữ nhật]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} màn hình.
# Đảo chiều ngang của tất cả đối tượng hình [tròn]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"}.
# Làm đảo chiều ngang vật thể [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"})
# Flip theo chiều ngang vật thể hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [70]{"entity": "position", "role": "source_y"})
# Lật ngược theo phương ngang của đối tượng hình [oval]{"entity": "object", "role": "shape"} ở [góc phải trên]{"entity": "position", "role": "source"}
# Lật theo chiều ngang của vật thể hình [ellipse]{"entity": "object", "role": "shape"}.
# Lật ngang
# Làm đảo chiều ngang tất cả vật thể [tam giác]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"} ở [tọa độ]{"entity": "aspect"} ([40]{"entity": "position", "role": "source_x"}, [51]{"entity": "position", "role": "source_y"})
# Flip theo chiều ngang vật thể hình [vuông]{"entity": "object", "role": "shape"} màu [hồng]{"entity": "object", "role": "color"}
# Lật ngược theo phương ngang của đối tượng hình [oval]{"entity": "object", "role": "shape"}.
# Đảo chiều ngang của vật thể ở [giữa]{"entity": "position", "role": "source"} màn hình.
# Lật hình [tam giác]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"} có [cạnh]{"entity": "aspect"} dài [100 pixel]{"entity": "object", "role": "width"}, [độ dày đường viền]{"entity": "aspect"} [2 pixel]{"entity": "object", "role": "thickness"}, nằm ở [vị trí]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [50]{"entity": "position", "role": "source_y"}) theo chiều ngang.
# Lật hình [tròn]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} có [bán kính]{"entity": "aspect"} [5 pixel]{"entity": "object", "role": "width"}, [độ dày đường viền]{"entity": "aspect"} [1 pixel]{"entity": "object", "role": "thickness"}, nằm ở [giữa]{"entity": "position", "role": "source"} màn hình theo chiều ngang.
# Lật hình [vuông]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} có [độ dài cạnh]{"entity": "aspect"} [8 pixel]{"entity": "object", "role": "height"}, [độ dày đường viền]{"entity": "aspect"} [3 pixel]{"entity": "object", "role": "thickness"}, nằm [bên phải phần dưới]{"entity": "position", "role": "source"} màn hình theo chiều ngang.
# Lật vật thể hình [tam giác]{"entity": "object", "role": "shape"} màu [xanh dương]{"entity": "object", "role": "color"}, [độ dài đáy]{"entity": "aspect"} [60 pixel]{"entity": "object", "role": "length"} và [chiều cao]{"entity": "aspect"} [100 pixel]{"entity": "object", "role": "height"}, ở [giữa phía trên]{"entity": "position", "role": "source"} trang, không cần chỉ định đường viền.
# Đảo ngược [vị trí]{"entity": "aspect"} của hình [tròn]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} ở [góc trái trên]{"entity": "position", "role": "source"} theo chiều ngang.
# Hãy lật ngang hình [chữ nhật]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"}{"entity": "object", "role": "color"}, [kích thước]{"entity": "aspect"} [20]{"entity": "object", "role": "length"}x[30]{"entity": "object", "role": "width"} pixel và có [độ dày đường viền]{"entity": "aspect"} [2 pixel]{"entity": "object", "role": "thickness"}.
# Lật hình [tròn]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} nằm ở [vị trí]{"entity": "aspect"} ([200]{"entity": "position", "role": "source_x"}, [100]{"entity": "position", "role": "source_y"}), có [đường kính]{"entity": "aspect"} [12 cm]{"entity": "object", "role": "length"}, [độ dày đường viền]{"entity": "aspect"} [5 px]{"entity": "object", "role": "thickness"} theo chiều ngang.
# ngang lật
# hướng ngang lật
# lật theo hướng ngang
# vợ yêu lật cho anh những cái đã chọn hướng nằm ngang nào
# anh cần em lật cho anh theo hướng ngang
# lật càng ngang càng tốt
# mấy cái đã chọn mà lật ngang được thì tốt
# Lật ngang hình [vuông]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} hai hình vuông màu [cam]{"entity": "object", "role": "color"}
# Thực hiện lật ngang đối tượng đã được chọn .
# Lật [tam giác]{"entity": "object", "role": "shape"} ở [tọa độ]{"entity": "aspect"} ( [8]{"entity": "position", "role": "source_x"} , [15]{"entity": "position", "role": "source_y"}
# Lật toàn bộ hình ảnh theo chiều ngang để tạo hiệu ứng đối xứng .
# Lật ngang hình [chữ nhật]{"entity": "object", "role": "shape"} đã chọn để thay đổi [hình dạng]{"entity": "aspect"}
# Thực hiện lật ngang hình [tròn]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} màu [cam]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"}
# Lật ngang một [hình thang]{"entity": "object", "role": "shape"} từ [vị trí]{"entity": "aspect"}
# Lật ngang hình [tam giác]{"entity": "object", "role": "shape"}
# Thực hiện lật ngang đối tượng [chữ nhật]{"entity": "object", "role": "shape"} ở [tọa độ]{"entity": "aspect"} ( [12]{"entity": "position", "role": "source_x"} , [8]{"entity": "position", "role": "source_y"}
# Lật ngang hình [tròn]{"entity": "object", "role": "shape"}
# Lật ngang hình [thoi]{"entity": "object", "role": "shape"}
# Thực hiện lật ngang đối tượng hình [bình hành]{"entity": "object", "role": "shape"}
# Lật ngang hình [ngôi sao]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [5]{"entity": "position", "role": "source_x"} , [10]{"entity": "position", "role": "source_y"}
# Lật ngang hình [chóp]{"entity": "object", "role": "shape"} từ [vị trí]{"entity": "aspect"}
# Hãy lật hình [trái tim]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ( [20]{"entity": "position", "role": "source_x"}, [32]{"entity": "position", "role": "source_y"}) theo phương ngang.
# Lật dọc hình [chữ nhật]{"entity": "object", "role": "shape"} ở [góc phải trên]{"entity": "position", "role": "source"}
# Đảo chiều dọc của đối tượng hình [tròn]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} màn hình.
# Làm đảo chiều dọc vật thể [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([55]{"entity": "position", "role": "source_x"}, [31]{"entity": "position", "role": "source_y"})
# Flip xuống dưới theo chiều dọc của vật thể hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [70]{"entity": "position", "role": "source_y"})
# Lật lên trên đối tượng hình [oval]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"}
# Đảo chiều dọc của vật thể hình [ngôi sao]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"}
# Làm đảo theo chiều dọc vật thể hình [ellipse]{"entity": "object", "role": "shape"} màu [xanh dương]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"})
# Lật theo phương thẳng đứng hình [chữ nhật]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"}
# Lật dọc đối tượng hình [thang]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} ở [góc trái dưới]{"entity": "position", "role": "source"} màn hình
# Đảo theo chiều dọc hình [ngôi sao]{"entity": "object", "role": "shape"} màu [tím]{"entity": "object", "role": "color"} ở [tọa độ]{"entity": "aspect"} ([40]{"entity": "position", "role": "source_x"}, [0]{"entity": "position", "role": "source_y"})
# Lật vật thể hình [vuông]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"}, có [kích thước]{"entity": "aspect"} [100]{"entity": "object", "role": "length"}x[100]{"entity": "object", "role": "height"} pixel], ở [vị trí]{"entity": "aspect"} ([200]{"entity": "position", "role": "source_x"}, [300]{"entity": "position", "role": "source_y"}) và có [độ dày đường viền]{"entity": "aspect"} là [5 pixel]{"entity": "object", "role": "thickness"} theo chiều dọc.
# Lật vật thể hình [tròn]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"}, ở [bên phải]{"entity": "position", "role": "source"} màn hình và có [độ dày đường viền]{"entity": "aspect"} là [3 pixel]{"entity": "object", "role": "thickness"} theo chiều dọc.
# Lật vật thể hình [tam giác]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"}, có [kích thước]{"entity": "aspect"} [150]{"entity": "object", "role": "height"}x[200]{"entity": "object", "role": "length"} pixel và ở [giữa]{"entity": "position", "role": "source"} màn hình theo chiều dọc.
# Lật vật thể hình [chữ nhật]{"entity": "object", "role": "shape"} màu [tím]{"entity": "object", "role": "color"}, có [độ dày đường viền]{"entity": "aspect"} là [2 pixel]{"entity": "object", "role": "thickness"}, ở [vị trí]{"entity": "aspect"} ([100]{"entity": "position", "role": "source_x"}, [200]{"entity": "position", "role": "source_y"}) và có [chiều dài]{"entity": "aspect"} [200 pixel]{"entity": "object", "role": "length"} và [chiều rộng]{"entity": "aspect"} [100 pixel]{"entity": "object", "role": "width"} theo chiều dọc.
# Lật vật thể hình [sao]{"entity": "object", "role": "shape"} màu [cam]{"entity": "object", "role": "color"}, ở [bên trái]{"entity": "position", "role": "source"} màn hình và có [kích thước]{"entity": "aspect"} [100]{"entity": "object", "role": "width"}x[100]{"entity": "object", "role": "length"} pixel theo chiều dọc.
# lật dọc đê
# lật theo [trục]{"entity": "aspect"}
# ồi ôi bạn trợ lý xinh xắn lật dọc đối tượng đó cho tôi nhé
# bạn hãy lật dọc các đối tượng đã chọn
# bạn có thể lật theo chiều dọc cho mềnh khum
# em yêu lật dọc những cái đã chọn cho anh nhé
# đỉnh quá , bước tới dọc lật cho tôi nhé
# dọc lật
# lật dọc hướng
# Lật dọc hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [5]{"entity": "position", "role": "source_x"} , [10]{"entity": "position", "role": "source_y"}
# Thực hiện lật dọc đối tượng đã được chọn .
# Lật hình [tam giác]{"entity": "object", "role": "shape"} tại [vị trí]{"entity": "aspect"} ( [8]{"entity": "position", "role": "source_x"} , [15]{"entity": "position", "role": "source_y"}
# Lật toàn bộ hình ảnh theo chiều dọc để thay đổi [góc nhìn]{"entity": "aspect"}
# Lật dọc hình [chữ nhật]{"entity": "object", "role": "shape"}
# Thực hiện lật dọc hình [tròn]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [2]{"entity": "position", "role": "source_x"} , [5]{"entity": "position", "role": "source_y"}
# Lật dọc hình [thang]{"entity": "object", "role": "shape"} từ [vị trí]{"entity": "aspect"}
# Lật dọc hình [tam giác]{"entity": "object", "role": "shape"}
# Thực hiện lật dọc đối tượng [chữ nhật]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [12]{"entity": "position", "role": "source_x"} , [8]{"entity": "position", "role": "source_y"}
# Lật dọc hình [tròn]{"entity": "object", "role": "shape"} hiện tại để thay đổi [hình dạng]{"entity": "aspect"}
# Lật dọc hình [vuông]{"entity": "object", "role": "shape"} tại [vị trí]{"entity": "aspect"} [giữa]{"entity": "position", "role": "source"} hai hình vuông màu [cam]{"entity": "object", "role": "color"}
# Lật toàn bộ đối tượng đã chọn theo chiều dọc để tạo hiệu ứng đối xứng .
# Lật dọc hình [thoi]{"entity": "object", "role": "shape"} đã chọn để thay đổi [hình dạng]{"entity": "aspect"}
# Thực hiện lật dọc hình [tròn]{"entity": "object", "role": "shape"} tại [vị trí]{"entity": "aspect"} màu [cam]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"}
# Lật dọc hình [ngôi sao]{"entity": "object", "role": "shape"}
# Thực hiện lật dọc đối tượng [tam giác]{"entity": "object", "role": "shape"} tại [vị trí]{"entity": "aspect"} ( [0]{"entity": "position", "role": "source_x"} , [0]{"entity": "position", "role": "source_y"}
# Lật dọc hình hiện tại để tạo hiệu ứng phản chiếu .
# Di chuyển vật thể hình [chữ nhật]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} về bên trái [5 đơn vị]{"entity": "value", "role": "move"}
# Dời đối tượng hình [tròn]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"} qua bên trái [10 pixel]{"entity": "value", "role": "move"}
# Làm di chuyển vật thể [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"}) sang trái [20 cm]{"entity": "value", "role": "move"}
# Dịch chuyển vật thể hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [70]{"entity": "position", "role": "source_y"}) qua bên trái [30 điểm ảnh]{"entity": "value", "role": "move"}
# Di chuyển vật thể hình [oval]{"entity": "object", "role": "shape"} ở [góc trái trên]{"entity": "position", "role": "source"} về bên trái [15 đơn vị]{"entity": "value", "role": "move"}
# Điều chỉnh [vị trí]{"entity": "aspect"} của vật thể hình [tròn]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} [chính giữa]{"entity": "position", "role": "source"} màn hình sang trái khoảng [50 pixel]{"entity": "value", "role": "move"}
# Dịch vật thể [tam giác]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} [góc phải trên]{"entity": "position", "role": "source"} màn hình sang trái [20 cm]{"entity": "value", "role": "move"}
# Di chuyển vật thể hình [oval]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} về bên trái [15 đơn vị]{"entity": "value", "role": "move"}
# Điều chỉnh [vị trí]{"entity": "aspect"} sang trái của vật thể hình [ngôi sao]{"entity": "object", "role": "shape"} màu [hồng]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} ([40]{"entity": "position", "role": "source_x"}, [50]{"entity": "position", "role": "source_y"}) khoảng [50 pixel]{"entity": "value", "role": "move"}
# Hãy di chuyển hình [thoi]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"} ở [giữa]{"entity": "position", "role": "source"} trang sang bên trái [20 pixel]{"entity": "value", "role": "move"}, với [đường chéo phụ]{"entity": "aspect"} [40 pixel]{"entity": "object", "role": "width"} và [đường chéo chính]{"entity": "aspect"} [30 pixel]{"entity": "object", "role": "length"}, [độ dày đường viền]{"entity": "aspect"} là [1 pixel]{"entity": "object", "role": "thickness"}.
# Di chuyển hình [tam giác]{"entity": "object", "role": "shape"} màu [xanh dương]{"entity": "object", "role": "color"} ở [góc trên bên phải]{"entity": "position", "role": "source"} sang bên trái [15 pixel]{"entity": "value", "role": "move"}, giữ nguyên [độ dài đáy]{"entity": "aspect"} là [60 pixel]{"entity": "object", "role": "length"} và không cần chỉ định đường viền.
# Lấy hình [chữ nhật]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} ở [giữa phía trên]{"entity": "position", "role": "source"} trang, di chuyển nó sang bên trái, không cần chỉ định [kích thước]{"entity": "aspect"}, và giữ nguyên [độ dày đường viền]{"entity": "aspect"} là [2 pixel]{"entity": "object", "role": "thickness"}.
# Trợ lý ơi, hãy đưa hình [tròn]{"entity": "object", "role": "shape"} màu [cam]{"entity": "object", "role": "color"} ở [góc phải dưới]{"entity": "position", "role": "source"} sang bên trái [30 pixel]{"entity": "value", "role": "move"}, với [đường viền]{"entity": "aspect"} dày [3 pixel]{"entity": "object", "role": "thickness"}, [kích thước]{"entity": "aspect"} không quan trọng.
# Di chuyển hình [vuông]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} ở [góc trái trên]{"entity": "position", "role": "source"} sang bên trái [18 pixel]{"entity": "value", "role": "move"}, giữ nguyên màu [sắc]{"entity": "aspect"} và [độ dày đường viền]{"entity": "aspect"} là [5 pixel]{"entity": "object", "role": "thickness"}, không cần chỉ định kích thước.
# Tôi muốn di chuyển hình [tam giác]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} có [độ dài]{"entity": "aspect"} [cạnh đáy]{"entity": "aspect"} là [8 cm]{"entity": "object", "role": "length"}, [chiều cao]{"entity": "aspect"} là [6 cm]{"entity": "object", "role": "height"}, nằm ở [giữa]{"entity": "position", "role": "source"} bản vẽ sang bên trái [15 pixel]{"entity": "value", "role": "move"}.
# Di chuyển hình [chữ nhật]{"entity": "object", "role": "shape"} màu [tím]{"entity": "object", "role": "color"} nằm ở [vị trí]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [100]{"entity": "position", "role": "source_y"}), có [kích thước]{"entity": "aspect"} [12 cm]{"entity": "object", "role": "length"} x [8 cm]{"entity": "object", "role": "width"}, [độ dày đường viền]{"entity": "aspect"} [4 px]{"entity": "object", "role": "thickness"} sang bên trái
# đi sang phía bên trái [5 đơn vị]{"entity": "value", "role": "move"}
# trợ lý ơi di chuyển sang trái [500 đơn vị]{"entity": "value", "role": "move"}
# em yêu di chuyển những cái được chọn cho anh sang bên trái nhé
# bạn di chuyển qua trái [500 đơn vị]{"entity": "value", "role": "move"}
# được rồi hãy cho những đối tượng được chọn qua bên trái [500 pixel]{"entity": "value", "role": "move"}
# qua trái
# trái [500 pixel]{"entity": "value", "role": "move"}
# qua trái [800]{"entity": "value", "role": "move"}
# tiến trái [1000 đơn vị]{"entity": "value", "role": "move"}
# lệch sang bên trái [309 đơn vị]{"entity": "value", "role": "move"}
# Di chuyển đối tượng hiện tại sang trái một khoảng [mặc định]{"entity": "value", "role": "move"}
# Dịch [hình vuông]{"entity": "object", "role": "shape"} màu [cam]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"}
# Thực hiện di chuyển sang trái đối tượng đã được chọn .
# Dịch [tam giác]{"entity": "object", "role": "shape"} sang trái từ vị trí hiện tại với khoảng cách [mặc định]{"entity": "value", "role": "move"}
# Dịch [hình chữ nhật]{"entity": "object", "role": "shape"} sang trái với khoảng cách di chuyển [mặc định]{"entity": "value", "role": "move"}
# Thực hiện di chuyển sang trái [hình tròn]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "object", "role": "shape"}
# Dịch [ngôi sao]{"entity": "object", "role": "shape"} sang trái từ [tọa độ]{"entity": "aspect"} ( [5]{"entity": "position", "role": "source_x"} , [10]{"entity": "position", "role": "source_y"}
# Di chuyển [hình thoi]{"entity": "object", "role": "shape"} sang trái với khoảng cách [mặc định]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Dịch [hình bình hành]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} màu [cam]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"}
# Thực hiện di chuyển sang trái hình [ngôi sao]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [8]{"entity": "position", "role": "source_x"} , [15]{"entity": "position", "role": "source_y"}
# Dịch [hình chóp]{"entity": "object", "role": "shape"} sang trái từ [vị trí]{"entity": "aspect"} hiện tại với khoảng cách [mặc định]{"entity": "value", "role": "move"}
# Di chuyển [hình tam giác]{"entity": "object", "role": "shape"} đã chọn sang trái một khoảng [nhỏ]{"entity": "value", "role": "move"} để điều chỉnh [vị trí]{"entity": "aspect"}
# Dịch [hình chữ nhật]{"entity": "object", "role": "shape"} sang trái với khoảng cách di chuyển [mặc định]{"entity": "value", "role": "move"}
# Thực hiện di chuyển sang trái [hình tròn]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"}
# Dịch [hình thoi]{"entity": "object", "role": "shape"} màu [cam]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"}
# Di chuyển [hình bình hành]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ( [2]{"entity": "position", "role": "source_x"} , [5]{"entity": "position", "role": "source_y"} ) sang trái để thay đổi [vị trí]{"entity": "aspect"}
# Thực hiện di chuyển sang trái hình [ngôi sao]{"entity": "object", "role": "shape"} với khoảng cách [mặc định]{"entity": "value", "role": "move"}
# Dịch [hình tam giác]{"entity": "object", "role": "shape"} sang trái từ [vị trí]{"entity": "aspect"}
# Di chuyển [hình chóp]{"entity": "object", "role": "shape"} sang trái với khoảng cách di chuyển [mặc định]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Dịch [tam giác]{"entity": "object", "role": "shape"} sang trái từ [vị trí]{"entity": "aspect"} hiện tại với khoảng cách [20 pixel]{"entity": "value", "role": "move"}
# Thực hiện di chuyển sang trái [hình tròn]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"} hai hình vuông với khoảng cách [15 pixel]{"entity": "value", "role": "move"}
# Dịch [hình bình hành]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"} hai hình thoi sang trái khoảng [10 pixel]{"entity": "value", "role": "move"}
# Dịch [hình chóp]{"entity": "object", "role": "shape"} sang trái từ [vị trí]{"entity": "aspect"} hiện tại với khoảng cách [25 pixel]{"entity": "value", "role": "move"}
# Thực hiện di chuyển sang trái [hình tròn]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"} hai hình tam giác với khoảng cách [12 pixel]{"entity": "value", "role": "move"}
# Dịch [hình thoi]{"entity": "object", "role": "shape"} sang trái ở [vị trí]{"entity": "aspect"} màu [cam]{"entity": "object", "role": "color"} nằm [bên]{"entity": "position", "role": "source"} trái hai hình vuông với khoảng cách [18 pixel]{"entity": "value", "role": "move"}
# Di chuyển hình [chữ nhật]{"entity": "object", "role": "shape"} ở [giữa bên trên]{"entity": "position", "role": "source"} màn hình về bên phải [5 đơn vị]{"entity": "value", "role": "move"}
# Dời hình [tròn]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"} qua bên phải [10 pixel]{"entity": "value", "role": "move"}
# Làm di chuyển hình vật thể [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"}) sang phải [20 cm]{"entity": "value", "role": "move"}
# Kéo vật thể hình [vuông]{"entity": "object", "role": "shape"} tại [tọa độ]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [70]{"entity": "position", "role": "source_y"}) qua bên phải [30 điểm ảnh]{"entity": "value", "role": "move"}
# Di chuyển ảnh vật thể hình [oval]{"entity": "object", "role": "shape"} ở [góc trái trên]{"entity": "position", "role": "source"} về bên phải [15 đơn vị]{"entity": "value", "role": "move"}
# Điều chỉnh [vị trí]{"entity": "aspect"} sang phải của hình ảnh vật thể hình [ngôi sao]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} khoảng [50 pixel]{"entity": "value", "role": "move"}
# Kéo hình [thoi]{"entity": "object", "role": "shape"} màu [xám]{"entity": "object", "role": "color"} về bên phải [5 đơn vị]{"entity": "value", "role": "move"}
# Dịch hình [tròn]{"entity": "object", "role": "shape"} màu [hồng]{"entity": "object", "role": "color"} qua bên phải [10 pixel]{"entity": "value", "role": "move"}
# Di chuyển ảnh vật thể hình [oval]{"entity": "object", "role": "shape"} màu [hồng]{"entity": "object", "role": "color"} ở [góc trái trên]{"entity": "position", "role": "source"} về bên phải [15 đơn vị]{"entity": "value", "role": "move"}
# Điều chỉnh [vị trí]{"entity": "aspect"} sang phải của hình ảnh vật thể hình [ngôi sao]{"entity": "object", "role": "shape"} màu [đen]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} ([60]{"entity": "position", "role": "source_x"}, [40]{"entity": "position", "role": "source_y"}) khoảng [50 pixel]{"entity": "value", "role": "move"}
# Di chuyển hình [tròn]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} có [bán kính]{"entity": "aspect"} [5 pixel]{"entity": "object", "role": "width"}, [độ dày đường viền]{"entity": "aspect"} [1 pixel]{"entity": "object", "role": "thickness"}, nằm ở [giữa]{"entity": "position", "role": "source"} màn hình sang bên phải [15 pixel]{"entity": "value", "role": "move"}.
# Di chuyển hình [vuông]{"entity": "object", "role": "shape"} màu [hồng]{"entity": "object", "role": "color"} ở [góc trên bên phải]{"entity": "position", "role": "source"} sang bên phải [5 pixel]{"entity": "value", "role": "move"}, giữ nguyên [kích thước]{"entity": "aspect"} của [cạnh]{"entity": "aspect"} là [50 pixel]{"entity": "object", "role": "height"} và không cần chỉ định [đường viền]{"entity": "aspect"}.
# Lấy hình [chữ nhật]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"} ở [giữa phía trên]{"entity": "position", "role": "source"} trang, di chuyển nó sang bên phải [20 pixel]{"entity": "object", "role": "thickness"}, không cần chỉ định [kích thước]{"entity": "aspect"}, và giữ nguyên [độ dày đường viền]{"entity": "aspect"} là [2 pixel]{"entity": "object", "role": "thickness"}.
# Di chuyển hình [vuông]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} có [độ dài]{"entity": "aspect"} [cạnh]{"entity": "aspect"} [8 pixel]{"entity": "object", "role": "height"}, [độ dày đường viền]{"entity": "object", "role": "color"} 3 pixel, nằm [bên phải phần trên]{"entity": "position", "role": "source"} màn hình sang bên phải [10 pixel]{"entity": "value", "role": "move"}.
# Di chuyển hình [thoi]{"entity": "object", "role": "shape"} màu [tím]{"entity": "object", "role": "color"} ở [góc trái trên]{"entity": "position", "role": "source"} sang bên phải, giữ nguyên màu [sắc]{"entity": "aspect"} là màu [đỏ]{"entity": "object", "role": "color"} và [độ dày đường viền]{"entity": "aspect"} là [2 pixel]{"entity": "object", "role": "thickness"}, không cần chỉ định [kích thước]{"entity": "aspect"}.
# Hãy di chuyển hình [vuông]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"} có [cạnh]{"entity": "aspect"} [5 cm]{"entity": "object", "role": "height"}, [độ dày đường viền]{"entity": "aspect"} [1 px]{"entity": "object", "role": "thickness"}, nằm ở [góc trên bên phải]{"entity": "position", "role": "source"} của bản vẽ sang bên phải [10 pixel]{"entity": "value", "role": "move"}.
# Tôi muốn di chuyển hình [tam giác]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} có [độ dài]{"entity": "aspect"} [cạnh đáy]{"entity": "aspect"} là [8 cm]{"entity": "object", "role": "length"}, [chiều cao]{"entity": "aspect"} là [6 cm]{"entity": "object", "role": "width"}, [độ dày đường viền]{"entity": "aspect"} [3 px]{"entity": "object", "role": "thickness"}, nằm ở [giữa]{"entity": "position", "role": "source"} bản vẽ sang bên phải [15 pixel]{"entity": "value", "role": "move"}.
# tiến sang phải
# sang phải 500
# di chuyển phải [300 pixel]{"entity": "value", "role": "move"}
# em bé của anh hãy đưa các đối tượng được chọn qua phải [200 đơn vị]{"entity": "value", "role": "move"}
# bạn di chuyển cho tôi sang bên phải nhé
# di sang phải [200 pixel]{"entity": "value", "role": "move"}
# tôi cần bạn di chuyển chúng sang bên phải
# tiến sang phải [1009 pixel]{"entity": "value", "role": "move"}
# Dịch [hình vuông]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} màu [cam]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"} hai hình vuông sang phải với khoảng cách [15 pixel]{"entity": "value", "role": "move"}
# Thực hiện di chuyển sang phải đối tượng đã được chọn với khoảng cách [mặc định]{"entity": "value", "role": "move"}
# Dịch [tam giác]{"entity": "object", "role": "shape"} sang phải từ [vị trí]{"entity": "aspect"} hiện tại với khoảng cách [20 pixel]{"entity": "value", "role": "move"}
# Di chuyển [toàn bộ hình ảnh]{"entity": "object", "role": "shape"} sang phải để điều chỉnh [vị trí]{"entity": "aspect"}
# Dịch [hình chữ nhật]{"entity": "object", "role": "shape"} sang phải với khoảng cách [mặc định]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Thực hiện di chuyển sang phải [hình tròn]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"} hai hình vuông với khoảng cách [12 pixel]{"entity": "value", "role": "move"}
# Dịch [ngôi sao]{"entity": "object", "role": "shape"} sang phải từ [tọa độ]{"entity": "aspect"} ( [5]{"entity": "position", "role": "source_x"} , [10]{"entity": "position", "role": "source_y"}
# Di chuyển [hình thoi]{"entity": "object", "role": "shape"} sang phải với khoảng cách [mặc định]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Dịch [hình bình hành]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"} hai hình tam giác sang phải với khoảng cách [10 pixel]{"entity": "value", "role": "move"}
# Thực hiện di chuyển sang phải hình [ngôi sao]{"entity": "object", "role": "shape"} với khoảng cách [30 pixel]{"entity": "value", "role": "move"}
# Dịch hình [chóp]{"entity": "object", "role": "shape"} sang phải từ [vị trí]{"entity": "aspect"} hiện tại với khoảng cách [25 pixel]{"entity": "value", "role": "move"}
# Di chuyển hình [tam giác]{"entity": "object", "role": "shape"} đã chọn sang phải một [khoảng nhỏ]{"entity": "value", "role": "move"} để điều chỉnh [vị trí]{"entity": "aspect"}
# Dịch hình [chữ nhật]{"entity": "object", "role": "shape"} sang phải với khoảng cách di chuyển [mặc định]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Thực hiện di chuyển sang phải [hình tròn]{"entity": "object", "role": "shape"} nằm [giữa]{"entity": "position", "role": "source"} hai hình vuông với khoảng cách [18 pixel]{"entity": "value", "role": "move"}
# Dịch hình [thoi]{"entity": "object", "role": "shape"} màu [xanh]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"} hai hình vuông sang phải với khoảng cách [22 pixel]{"entity": "value", "role": "change"}
# Di chuyển [hình bình hành]{"entity": "object", "role": "shape"} sang phải tại [tọa độ]{"entity": "aspect"} ( [2]{"entity": "position", "role": "source_x"} , [5]{"entity": "position", "role": "source_y"} ) để thay đổi [vị trí]{"entity": "aspect"}
# Thực hiện di chuyển sang phải hình [ngôi sao]{"entity": "object", "role": "shape"} với khoảng cách [mặc định]{"entity": "value", "role": "move"}
# Dịch hình [tam giác]{"entity": "object", "role": "shape"} sang phải từ [vị trí]{"entity": "aspect"}
# Di chuyển hình [chóp]{"entity": "object", "role": "shape"} sang phải với khoảng cách di chuyển [mặc định]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Dịch hình [thoi]{"entity": "object", "role": "shape"} sang phải [15 pixel]{"entity": "value", "role": "move"}
# Di chuyển hình [bình hành]{"entity": "object", "role": "shape"} sang phải [8 pixel]{"entity": "value", "role": "move"} từ [vị trí]{"entity": "aspect"}
# Thực hiện di chuyển sang phải hình [ngôi sao]{"entity": "object", "role": "shape"} với khoảng cách [25 pixel]{"entity": "value", "role": "move"}
# Dịch hình [tam giác]{"entity": "object", "role": "shape"} sang phải từ [vị trí]{"entity": "aspect"} hiện tại với khoảng cách [15 pixel ]{"entity": "value", "role": "move"}
# Di chuyển sang phải [hình vuông]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} nằm [giữa]{"entity": "position", "role": "source"} hai hình vuông với khoảng cách [20 pixel]{"entity": "value", "role": "move"}
# Di chuyển hình vật thể hình [chữ nhật]{"entity": "object", "role": "shape"} ở [giữa]{"entity": "position", "role": "source"} lên trên [5 đơn vị]{"entity": "value", "role": "move"}
# Dời hình [tròn]{"entity": "object", "role": "shape"} ở [góc trái dưới]{"entity": "position", "role": "source"} lên trên [10 pixel]{"entity": "value", "role": "move"}
# Làm di chuyển lên vật thể [tam giác]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [30]{"entity": "position", "role": "source_y"})
# Move hình ảnh vật thể hình [vuông]{"entity": "object", "role": "shape"} lên trên [30 điểm ảnh]{"entity": "value", "role": "move"}
# Di chuyển ảnh vật thể hình [oval]{"entity": "object", "role": "shape"} lên trên [15 đơn vị]{"entity": "value", "role": "move"}
# Điều chỉnh hình [chữ nhật]{"entity": "object", "role": "shape"} màu [xám]{"entity": "object", "role": "color"} dịch chuyển lên trên khoảng [50 pixel]{"entity": "value", "role": "move"}
# Move hình ảnh vật thể hình [vuông]{"entity": "object", "role": "shape"} ở [vị trí]{"entity": "aspect"} ([20]{"entity": "position", "role": "source_x"}, [50]{"entity": "position", "role": "source_y"}) lên trên [30 điểm ảnh]{"entity": "value", "role": "move"}
# Di chuyển ảnh vật thể hình [oval]{"entity": "object", "role": "shape"} màu [tím]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} [chính giữa]{"entity": "position", "role": "source"} màn hình lên trên [15 đơn vị]{"entity": "value", "role": "move"}
# Điều chỉnh [vị trí]{"entity": "aspect"} lên trên của hình [ngôi sao]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} ở [vị trí]{"entity": "aspect"} ([30]{"entity": "position", "role": "source_x"}, [15]{"entity": "position", "role": "source_y"}) khoảng [50 pixel]{"entity": "value", "role": "move"}
# Di chuyển hình [vuông]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"} có [kích thước]{"entity": "aspect"} [10]{"entity": "object", "role": "height"}x[10]{"entity": "object", "role": "height"} pixel, [độ dày đường viền]{"entity": "aspect"} [2 pixel]{"entity": "object", "role": "thickness"}, nằm ở [vị trí]{"entity": "aspect"} ([50]{"entity": "position", "role": "source_x"}, [50]{"entity": "position", "role": "source_y"}) lên phía trên [20 pixel]{"entity": "value", "role": "move"}.
# Di chuyển hình [tròn]{"entity": "object", "role": "shape"} màu [đỏ]{"entity": "object", "role": "color"} có [bán kính]{"entity": "aspect"} [5 pixel]{"entity": "object", "role": "width"}, [độ dày đường viền]{"entity": "aspect"} [1 pixel]{"entity": "object", "role": "thickness"}, nằm ở [giữa]{"entity": "position", "role": "source"} màn hình lên phía trên [15 pixel]{"entity": "value", "role": "move"}.
# Hãy di chuyển hình [vuông]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} ở [giữa phía trên]{"entity": "position", "role": "source"} trang lên phía trên [20 pixel]{"entity": "value", "role": "move"}, không cần chỉ định [kích thước]{"entity": "aspect"}, và giữ nguyên [độ dày đường viền]{"entity": "aspect"} là [2 pixel]{"entity": "object", "role": "thickness"}.
# Di chuyển hình [chữ nhật]{"entity": "object", "role": "shape"} màu [tím]{"entity": "object", "role": "color"} lên phía trên.
# Trợ lý ơi, đưa hình [tròn]{"entity": "object", "role": "shape"} màu [xanh lá cây]{"entity": "object", "role": "color"} ở [góc trái dưới]{"entity": "position", "role": "source"} lên trên [15 pixel]{"entity": "value", "role": "move"}, với [độ dày đường viền]{"entity": "aspect"} là [3 pixel]{"entity": "object", "role": "thickness"}, [kích thước]{"entity": "aspect"} không quan trọng
# Tôi muốn di chuyển hình [tam giác]{"entity": "object", "role": "shape"} màu [vàng]{"entity": "object", "role": "color"} có [độ dài]{"entity": "aspect"} [cạnh đáy]{"entity": "aspect"} là [8 cm]{"entity": "object", "role": "length"}, [chiều cao]{"entity": "aspect"} là [6 cm]{"entity": "object", "role": "height"}, nằm ở [giữa]{"entity": "position", "role": "source"} bản vẽ lên phía trên [15 pixel]{"entity": "value", "role": "move"}.
# ...
# Vẽ [mũi tên]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} tại [giữa]{"entity": "position", "role": "source"} bản vẽ , [chiều dài]{"entity": "aspect"} [60]{"entity": "value", "role": "length"} pixel , [chiều cao]{"entity": "aspect"} [80]{"entity": "value", "role": "height"} pixel , để tạo ra một [mũi tên]{"entity": "value", "role": "shape"}
# Tạo [mũi tên]{"entity": "value", "role": "shape"} màu [xanh lá cây]{"entity": "value", "role": "color"} tại [tọa độ]{"entity": "aspect"} ( [500]{"entity": "position", "role": "source_x"} , [300]{"entity": "position", "role": "source_y"} ) với [chiều cao]{"entity": "aspect"} [70]{"entity": "value", "role": "height"} pixel , [chiều dài]{"entity": "aspect"} [100]{"entity": "value", "role": "length"}
# Vẽ [mũi tên]{"entity": "value", "role": "shape"} màu [đỏ]{"entity": "value", "role": "color"} nằm [ngang]{"entity": "value", "role": "orientation"} [giữa]{"entity": "position", "role": "source"} màn hình , [chiều cao]{"entity": "aspect"} [80]{"entity": "value", "role": "width"} pixel , [chiều dài]{"entity": "aspect"} [120]{"entity": "value", "role": "length"} pixel , để tạo [điểm]{"entity": "aspect"}
# Tạo [mũi tên]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} tại [giữa]{"entity": "position", "role": "source"} bản vẽ , [chiều cao]{"entity": "aspect"} [90]{"entity": "value", "role": "width"} pixel , [chiều dài]{"entity": "aspect"} [110]{"entity": "value", "role": "length"}
# Vẽ [mũi tên]{"entity": "value", "role": "shape"} màu [tím]{"entity": "value", "role": "color"} nằm [dọc]{"entity": "position", "role": "destination"} [giữa]{"entity": "position", "role": "source"} màn hình , [chiều cao]{"entity": "aspect"} [80]{"entity": "value", "role": "height"} pixel , [chiều dài]{"entity": "aspect"} [120]{"entity": "value", "role": "length"}
# Tạo [mũi tên]{"entity": "value", "role": "shape"} màu [vàng]{"entity": "value", "role": "color"} ở [giữa]{"entity": "position", "role": "source"} bản vẽ , [chiều dài]{"entity": "aspect"} [60]{"entity": "value", "role": "length"} pixel , [chiều cao]{"entity": "aspect"} [80]{"entity": "value", "role": "height"}
# Vẽ [mũi tên]{"entity": "value", "role": "shape"} màu [cam]{"entity": "value", "role": "color"} ở [chính giữa]{"entity": "position", "role": "source"} , [chiều cao]{"entity": "aspect"} [90]{"entity": "value", "role": "height"} pixel , [chiều dài]{"entity": "aspect"} [110]{"entity": "value", "role": "length"}
# Tạo [mũi tên]{"entity": "value", "role": "shape"} màu [đen]{"entity": "value", "role": "color"} tại [tọa độ]{"entity": "aspect"} ( [200]{"entity": "position", "role": "source_x"} , [300]{"entity": "position", "role": "source_y"} ) với [chiều dài]{"entity": "aspect"} [80]{"entity": "value", "role": "length"} pixel , [chiều cao]{"entity": "aspect"} [60]{"entity": "value", "role": "height"} pixel , để tạo ra một chiếc [mũi tên]{"entity": "value", "role": "shape"}
# Vẽ [mũi tên]{"entity": "value", "role": "shape"} màu [hồng]{"entity": "value", "role": "color"} ở [góc trên cùng]{"entity": "position", "role": "source"} , [chiều cao]{"entity": "aspect"} [80]{"entity": "value", "role": "height"} pixel , [chiều dài]{"entity": "aspect"} [120]{"entity": "value", "role": "length"}
# Tạo [mũi tên]{"entity": "value", "role": "shape"} màu [đen]{"entity": "value", "role": "color"} tại [tọa độ]{"entity": "aspect"} ( [400]{"entity": "position", "role": "source_x"} , [100]{"entity": "position", "role": "source_y"} ) với [chiều rộng]{"entity": "aspect"} [80]{"entity": "value", "role": "width"} pixel , [chiều dài]{"entity": "aspect"} [120]{"entity": "value", "role": "length"}
# Sao chép vật thể đẫ được chọn từ trước.
# Hãy sao chép vật thể đang được chọn.
# Bạn chatbot ơi, copy hộ mình đối tượng đang được chọn với.
# Bạn có thể nhân bản những thứ này không vậy ?
# Trợ lý ơi , sao chép đám này giúp tôi đi .
# Tôi muốn có một bản copy của những thứ này .
# Nhái chúng giúp tôi , Trợ lý ơi .
# Bạn thể hiện khả năng nhân bản không ?
# Hãy làm cho chúng nhân đôi đấy !
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# Bạn có thể copy tất cả không ?
# Nhái những thứ này giúp tôi , bạn nhé .
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# Bạn có thể copy tất cả không ?
# Nhái những thứ này giúp tôi , bạn nhé .
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# Bạn có thể copy tất cả không ?
# Nhái những thứ này giúp tôi , bạn nhé .
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# Bạn có thể copy tất cả không ?
# Nhái những thứ này giúp tôi , bạn nhé .
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# Bạn có thể copy tất cả không ?
# Nhái những thứ này giúp tôi , bạn nhé .
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# Bạn có thể copy tất cả không ?
# Nhái những thứ này giúp tôi , bạn nhé .
# Tôi muốn tạo bản copy của chúng .
# Sao chép chúng với tốc độ ánh sáng !
# Nhân bản chúng đi , bạn ơi !
# Trợ lý , chúng ta cần một bản sao ngay bây giờ .
# cut.
# cắt.
# cắt những hình đang được chọn.
# Hãy cut các hình đang được chọn.
# Cắt các hình đang được lưu thông tin.
# Thực hiện cut
# Cut tất cả đối tượng được chọn
# Thực hiện lệnh cut với đối tượng đã chọn
# Tiến hành cut các đối tượng hiện tại
# Sử dụng cut để loại bỏ các đối tượng đã chọn
# Cut tất cả các đối tượng hiện tại
# Sử dụng lệnh cut để di chuyển đối tượng đã chọn
# Xóa các đối tượng hiện tại bằng cut
# Thực hiện cut để di chuyển các đối tượng được chọn
# Sử dụng cut để loại bỏ đối tượng hiện tại
# Cut đối tượng được chọn vào bộ nhớ tạm
# Tiến hành cut và lưu thông tin vào bộ nhớ tạm
# Thực hiện cut và xóa đối tượng đang chọn
# Cut các đối tượng được chọn và lưu vào bộ nhớ tạm
# Di chuyển đối tượng đã chọn bằng cut
# Sử dụng cut để tạm thời xóa các đối tượng
# Thực hiện cut để lưu thông tin và xóa đối tượng
# Cut tất cả đối tượng đang chọn và lưu vào bộ nhớ
# Tiến hành cut để di chuyển các đối tượng đã chọn
# Sử dụng lệnh cut để xóa đối tượng hiện tại
# Cut đối tượng được chọn và lưu vào bộ nhớ tạm
# Thực hiện cut để di chuyển và xóa các đối tượng
# Xóa tất cả đối tượng hiện tại bằng lệnh cut
# Sử dụng cut để lưu thông tin của đối tượng vào bộ nhớ
# Cut tất cả các đối tượng đang chọn và xóa chúng
# Thực hiện cut để tạm thời xóa các đối tượng được chọn
# Cut các đối tượng và lưu vào bộ nhớ tạm
# Sử dụng lệnh cut để di chuyển và lưu thông tin đối tượng
# Tiến hành cut để loại bỏ và lưu đối tượng vào bộ nhớ tạm
# Cut tất cả các đối tượng hiện tại và lưu thông tin
# Thực hiện cut để xóa và lưu thông tin của đối tượng
# Cut các đối tượng đang chọn và lưu vào bộ nhớ tạm thời
# Di chuyển đối tượng đã chọn bằng cut và lưu thông tin vào bộ nhớ
# Sử dụng cut để tạm thời xóa và lưu đối tượng đang chọn
# Cut tất cả đối tượng được chọn và lưu vào bộ nhớ tạm
# Thực hiện lệnh cut để xóa và lưu thông tin của đối tượng
# Cut các đối tượng hiện tại và lưu vào bộ nhớ tạm
# Sử dụng cut để di chuyển và xóa đối tượng đang chọn
# Tiến hành cut để xóa và lưu thông tin của đối tượng đã chọn
# Xóa tất cả đối tượng hiện tại bằng cut và lưu vào bộ nhớ
# Cut đối tượng được chọn và lưu thông tin vào bộ nhớ tạm
# Thực hiện cut để di chuyển và lưu đối tượng đã chọn
# Sử dụng cut để tạm thời xóa và lưu thông tin của đối tượng
# Cut tất cả các đối tượng đang chọn và lưu vào bộ nhớ
# Di chuyển đối tượng đã chọn bằng cut và lưu thông tin vào bộ nhớ
# Sử dụng lệnh cut để xóa và lưu thông tin của đối tượng hiện tại
# Cut các đối tượng hiện tại và lưu vào bộ nhớ tạm thời
# Thực hiện cut để xóa và lưu thông tin của đối tượng đang chọn
# Cut các đối tượng được chọn và lưu vào bộ nhớ tạm
# dán
# paste
# in những cái đã copy
# hãy dán hình đã cắt vào [bên phải trên]{"entity": "position", "role": "destination"} màn hình
# oke dán vào [bên dưới]{"entity": "position", "role": "destination"}
# in vào ([23]{"entity": "position", "role": "destination_x"}, [54]{"entity": "position", "role": "destination_y"}
# dán lên [bên trên]{"entity": "position", "role": "destination"}
# chắc bạn dán vào [trung tâm]{"entity": "position", "role": "destination"}
# oke bạn dán vào [bên phải]{"entity": "position", "role": "destination"}
# Bên [phải trên]{"entity": "position", "role": "destination"}
# Oke , dán vào [bên dưới]{"entity": "position", "role": "destination"}
# In vào ( [23]{"entity": "position", "role": "destination_x"} , [54]{"entity": "position", "role": "destination_y"}
# Dán lên [bên trên]{"entity": "position", "role": "destination"}
# Chắc bạn dán vào [trung tâm]{"entity": "position", "role": "destination"}
# Oke , bạn dán vào [bên phải]{"entity": "position", "role": "destination"}
# Dán vào [góc trái trên]{"entity": "position", "role": "destination"}
# Dán lên bên [dưới cùng]{"entity": "position", "role": "destination"}
# Dán vào [điểm]{"entity": "aspect"} ( [400]{"entity": "position", "role": "destination_x"} , [300]{"entity": "position", "role": "destination_y"}
# Dán vào [giữa trái]{"entity": "position", "role": "destination"}
# Dán vào [góc phải dưới]{"entity": "position", "role": "destination"}
# Oke , dán vào [bên trái trên]{"entity": "position", "role": "destination"}
# In vào ( [150]{"entity": "position", "role": "destination_x"} , [200]{"entity": "position", "role": "destination_y"}
# Dán lên bên [phải cùng]{"entity": "position", "role": "destination"}
# Dán vào [giữa phải]{"entity": "position", "role": "destination"}
# Dán vào [góc trái dưới]{"entity": "position", "role": "destination"}
# Paste ngay vào [giữa]{"entity": "position", "role": "destination"} trang , như người ta nói " đắp đá , nén cỏ " , cứ [giữa]{"entity": "position", "role": "destination"} trái trái [giữa]{"entity": "position", "role": "destination"}
# Oke , dán đi như cách bạn dán lòng mình vào mỗi mối quan hệ - không để lại khoảng trống nào cả !
# Paste vào [đây]{"entity": "position", "role": "destination"}
# Dán , vì cuộc sống không có nghĩa nếu không thể paste những điều tốt đẹp vào nó .
# In vào [điểm]{"entity": "aspect"} ( [23]{"entity": "position", "role": "destination_x"} , [54]{"entity": "position", "role": "destination_y"}
# Oke , chúng ta sẽ dán lên [bên trên]{"entity": "position", "role": "destination"}
# Dán lên bên [phải cùng]{"entity": "position", "role": "destination"} , cho đến khi nào cả trang đều được " đánh dấu " bởi sự vui vẻ và [màu sắc]{"entity": "aspect"}
# Dán vào [góc trái trên]{"entity": "position", "role": "destination"}
# Chắc chắn , bạn sẽ dán vào [bên trái trên]{"entity": "position", "role": "destination"}
# Oke , bạn dán vào [bên trái trên]{"entity": "position", "role": "destination"}
# Paste vào [giữa trái]{"entity": "position", "role": "destination"}
# Dán vào [bên trái trên]{"entity": "position", "role": "destination"}
# In vào [điểm]{"entity": "aspect"} ( [150]{"entity": "position", "role": "destination_x"} , [200]{"entity": "position", "role": "destination_y"}
# Dán lên bên [phải cùng]{"entity": "position", "role": "destination"}
# Paste vào [giữa phải]{"entity": "position", "role": "destination"} màn hình , giống như là đang xác định một " [điểm]{"entity": "aspect"}
# Dán vào [góc trái dưới]{"entity": "position", "role": "destination"}
# Dán lên [bên trên]{"entity": "position", "role": "destination"} , bởi vì bề ngoài có vẻ [đẹp hơn]{"entity": "comparison", "role": "bigger"}
# Dán vào [bên phải]{"entity": "position", "role": "destination"} nhé , như là chúng ta cần một ít " đối lập " để cuộc sống trở nên [thú vị hơn]{"entity": "comparison", "role": "bigger"}
# Dán vào [góc trái dưới]{"entity": "position", "role": "destination"}
# Dán lên bên trên , vì bề ngoài có vẻ [đẹp hơn]{"entity": "comparison", "role": "bigger"}
# làm lại bước mới nhất
# làm lại hành động vừa xong đi
# không cần undo nữa, vẫn làm động tác như lúc nãy
# bạn ctrl + Y cho tôi nhé
# Tiếp tục hành động vừa undo .
# Làm lại bước mới nhất đi .
# Không cần undo nữa , vẫn làm động tác như lúc nãy .
# Bạn ctrl + Y cho tôi nhé .
# Hãy redo lại hành động đã undo trước đó .
# Làm lại bước cuối cùng vừa được undo .
# Quay lại trạng thái trước khi thực hiện hành động undo .
# Đừng undo nữa , hãy tiếp tục hành động .
# Ctrl + Y để redo hành động cuối cùng .
# Làm lại thao tác vừa xong đi .
# Ồ , đừng undo mà quay lại trạng thái đã thực hiện .
# Tiếp tục hành động vừa undo trước đó .
# Ctrl + Y để làm lại bước cuối cùng .
# Không cần undo nữa , vẫn tiếp tục thực hiện các thao tác như bình thường .
# Quay lại trạng thái trước khi undo .
# Làm lại hành động vừa xong đi .
# Ồ , đừng undo nữa , hãy tiếp tục thao tác như lúc nãy .
# Ctrl + Y để làm lại hành động mới nhất .
# Quay lại trạng thái trước khi undo lần trước .
# Tiếp tục hành động vừa được undo .
# Làm lại bước cuối cùng đi .
# Không cần undo nữa , hãy tiếp tục thao tác như lúc nãy .
# Bạn ctrl + Y cho tôi nhé .
# Hãy redo lại hành động đã undo trước đó .
# Làm lại bước cuối cùng vừa được undo .
# Quay lại trạng thái trước khi thực hiện hành động undo .
# Đừng undo nữa , hãy tiếp tục hành động .
# Ctrl + Y để redo hành động cuối cùng .
# Làm lại thao tác vừa xong đi .
# Ồ , đừng undo mà quay lại trạng thái đã thực hiện .
# Tiếp tục hành động vừa undo trước đó .
# Ctrl + Y để làm lại bước cuối cùng .
# Không cần undo nữa , vẫn tiếp tục thực hiện các thao tác như bình thường .
# Quay lại trạng thái trước khi undo .
# Làm lại hành động vừa xong đi .
# Ồ , đừng undo nữa , hãy tiếp tục thao tác như lúc nãy .
# Ctrl + Y để làm lại hành động mới nhất .
# Quay lại trạng thái trước khi undo lần trước .
# Tiếp tục hành động vừa được undo .
# Làm lại bước cuối cùng đi .
# Không cần undo nữa , hãy tiếp tục thao tác như lúc nãy .
# Bạn ctrl + Y cho tôi nhé .
# Hãy redo lại hành động đã undo trước đó .
# Làm lại bước cuối cùng vừa được undo .
# Quay lại trạng thái trước khi thực hiện hành động undo . s
# quay lại bước trước
# trở về trạng thái trước
# undo
# quay trở về lúc nãy
# undo lại cho tôi
# trợ lý ơi trạng thái trước đó ấy, quay lại cho tôi nhé
# trở về bước vừa xong
# từ từ undo lại đi đã
# ôi không tôi cần quay lại bước lúc nãy
# Quay lại bước trước
# Trở về trạng thái trước
# Undo
# Quay trở về lúc nãy
# Undo lại cho tôi
# Trợ lý ơi , trạng thái trước đó ấy , quay lại cho tôi nhé
# Trở về bước vừa xong
# Từ từ undo lại đi đã
# Ôi không , tôi cần quay lại bước lúc nãy
# Đã xong , trở về trạng thái trước đó
# Undo tất cả những gì đã làm
# Hủy bỏ tất cả các thay đổi
# Quay lại bước trước đó , đừng giữ lại gì cả
# Trợ lý ơi , hãy quay trở lại lúc chưa làm gì cả
# Khôi phục trạng thái trước
# Undo lại , đưa tôi về trạng thái trước đó
# Trở về trạng thái lúc mới bắt đầu
# Hủy bỏ mọi thay đổi vừa rồi
# Quay lại trạng thái trước đó , xin đừng giữ lại gì cả .
# Làm ơn undo tất cả những thay đổi vừa rồi
# Trở lại trạng thái trước đó , không giữ lại gì cả
# Undo hết , quay lại lúc chưa thay đổi gì cả
# Quay lại bước trước , đừng giữ lại
# Trở về trạng thái lúc mới mở phần mềm
# Đã xong , undo cho tôi đi
# Quay về trạng thái ban đầu , không giữ lại gì
# Trở lại như chưa từng làm gì cả
# Undo hết , trở lại trạng thái trước đây
# Làm ơn hoàn tác tất cả thay đổi
# Quay về trạng thái trước , đừng giữ lại
# Undo mọi thứ , trở lại ban đầu
# Trở lại lúc chưa thực hiện thay đổi
# Làm ơn quay về trạng thái trước những sửa đổi
# Hủy bỏ mọi thay đổi , quay lại lúc mới bắt đầu
# Trở lại bước trước đó , không giữ lại gì cả
# Undo tất cả những gì đã thực hiện
# Làm ơn hoàn tác lại , không giữ lại bất kỳ sự thay đổi nào
# Quay về lúc chưa thay đổi gì , undo hết đi
# Trở lại trạng thái trước đó , không giữ lại thay đổi nào

# %%
total = 0
for entities in df["entities"]:
  # print(len(entities))
  total += len(entities)
total
# Out:
# 858

# %% [markdown]
# # load NLU dataset

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (1.10.1+cu111)
# Requirement already satisfied: typing-extensions in /workspace/nlplab/quannd/rasa_env_3.4/lib/python3.8/site-packages (from torch) (4.8.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from typing import List, Dict, Text, Any, Union

import pandas as pd
import torch

# %%
class DIETClassifierDataset:
  def __init__(self, dataframe: pd.Dataframe, tokenizer, entities: List[str], intents: List[str]):

    """
    params:
    - dataframe: dataframe contains ["example", "intent", "entities"] columns
    - tokenizer: pretrained tokenizer from transformers
    - entities: list of entities class names
    - intents: list of intents class names
    """

    dataframe = dataframe[dataframe["intent"].isin(intents)]

    self.entities = ["O"] + entities
    dataframe["entities"] = dataframe["entities"].apply(self._remove_entities)

    self.tokenizer = tokenizer
    self.num_entities = len(self.entities)
    self.intents = intents
    self.num_intents = len(intents)

    sentences = dict(
        sentences = [],
        entities = [],
        intent = []
    )

    for _, row in dataframe.iterrows():
      sentences["sentence"].append(row["example"])
      sentences["entities"].append(row["entities"])
      sentences["intent"].append(row["intent"])

    sentences.update(tokenizer(sentences["sentence"],
                               return_tensors="pt",
                               return_offsets_mapping=True,
                               padding="max_length",
                               truncation=True,
                               max_length=512))

    sentences["entites_labels"] = []

    for index in range(len(sentences["sentence"])):
      entities_labels = []
      for offset in sentences["offset_mapping"][index][1:]: # iterate in a list of dicts or tuples
        is_label = False
        if not (offset[0] == 0 and offset[1] == 0): # if that offet mapping is not in the beginning of sentence
          for entity in sentences["entities"][index]: # iterate in a list of dict entity. a dict entity contains position (tuple), entity_name (str), entity_value (str)
            if entity["possition"][0] <= offset[0] and entity["position"][1] >= offset[1]: # if entity contains >= 1 tokens
              entities_labels.append(self.entities.index(entity["entity_name"])) # assign these contained tokens with entity_name of dict entity
              is_label = True
        if not is_label:
          entities_labels.append(self.entities.index("O")) # assign other tokens with entity "O"

      sentences["entities_labels"].append(entities_labels)

    sentences["entities_labels"] = torch.tensor(sentences["entities_labels"])
    sentences["intent_labels"] = torch.tensor([self.intent.index(intent) for intent in sentences["intent"]])

    self.data = sentences

    def __len__(self, index) -> Dict[Text, Any]:
      item = dict(
          input_ids=self.data["input_ids"][index],
          token_type_ids=self.data["token_type_ids"][index],
          attention_mask=self.data["attention_mask"][index],
          entities_labels=self.data["entites_labels"][index],
          intent_labels=self.data["intent_labels"][index]
      )
      return item

    def _remove_entities(self, entities_list: Union[str, List[str, Any]]) -> List[Dict[str, Any]]:
       if isinstance(entities_list, str):
        try:
          entities_list = json.loads(entities_list)
        except Exception as ex:
          raise RuntimeError(f"Cannot convert entity {entities_list} by error: {ex}")

        entities_list = [entity for entity in entities_list if entity["entity_name"] in self.entities]
        return entities_list

# %%
- rotate_left
- rotate_right
- horizontal_flip
- vertical_flip
- move_left
- move_right
- move_up
- move_down
- select_object
- select_area
- delete_object
- delete_selected_objects
- color_all_background
- color_all_object
- color_selected_area
- change_width.
- change_height.
- change_length.
- change_radius.
- draw_circle
- draw_elip
- draw_rectangle
- draw_square
- draw_rhombus
- draw_parallelogram
- draw_trapezoid
- draw_line
- draw_cylinder
- draw_cube
- copy_object
- paste_object
